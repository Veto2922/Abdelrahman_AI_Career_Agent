# %%
5+5
# Out:
# 10

# %%
import os 
from dotenv import load_dotenv
from pageindex import PageIndexClient
from langchain.chat_models import init_chat_model
from loguru import logger

load_dotenv()

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
Page_index_api = os.getenv("Page_index_api")


pi_client = PageIndexClient(api_key =Page_index_api )
model = init_chat_model("google_genai:gemini-2.5-flash-lite" , api_key = GOOGLE_API_KEY)

# %% [markdown]
# # Get pdfs titles

# %%
docs_list =  pi_client.list_documents()

# %%
docs_list
# Out:
# {'documents': [{'id': 'pi-cmnnmjex1016w01qv2ej4ay36',
#    'name': 'projects_portfolio_in_github.pdf',
#    'description': 'This document outlines a data science portfolio showcasing projects in data analysis, visualization, machine learning, recommendation systems, time series forecasting, deep learning, and natural language processing.',
#    'status': 'completed',
#    'createdAt': '2026-04-06T20:09:43.265000',
#    'pageNum': 5,
#    'folderId': None},
#   {'id': 'pi-cmnnmjdi9016t01qvslbcf577',
#    'name': 'my_Linkedin.pdf',
#    'description': 'This document outlines the experience of Abdelrahman Mohamed, an AI Engineer specializing in LLM agents, RAG pipelines, and real-time AI assistants, with roles at Electro Pi, Sand Technologies, and ALX Arabia.',
#    'status': 'completed',
#    'createdAt': '2026-04-06T20:09:41.437000',
#    'pageNum': 4,
#    'folderId': None},
#   {'id': 'pi-cmnnmjcdr016q01qvn3cwv3ub',
#    'name': 'Abdelrahman_Mohamed_CV_14.9_1.pdf',
#    'description': 'This document is a resume for Abdelrahman Mohamed, an AI/ML Engineer with experience in GenAI systems, LLM fine-tuning, RAG pipelines, and real-time voice assistants, with a focus on Arabic AI applications.',
#    'status': 'completed',
#    'createdAt': '2026-04-06T20:09:39.983000',
#    'pageNum': 2,
#    'folderId': None}],
#  'total': 3,
#  'limit': 50,
#  'offset': 0}

# %%
docs_list['documents'][0]
# Out:
# {'id': 'pi-cmnnmjex1016w01qv2ej4ay36',
#  'name': 'projects_portfolio_in_github.pdf',
#  'description': 'This document outlines a data science portfolio showcasing projects in data analysis, visualization, machine learning, recommendation systems, time series forecasting, deep learning, and natural language processing.',
#  'status': 'completed',
#  'createdAt': '2026-04-06T20:09:43.265000',
#  'pageNum': 5,
#  'folderId': None}

# %%
docs_titles = []

for i in range(len(docs_list['documents'])):

    doc = {
            "id" : i,
            "name" : docs_list['documents'][i]['name'],
            "description": docs_list['documents'][i]['description']

    }
    docs_titles.append(doc)
    print(docs_titles)
# Out:
# [{'id': 0, 'name': 'projects_portfolio_in_github.pdf', 'description': 'This document outlines a data science portfolio showcasing projects in data analysis, visualization, machine learning, recommendation systems, time series forecasting, deep learning, and natural language processing.'}]
# [{'id': 0, 'name': 'projects_portfolio_in_github.pdf', 'description': 'This document outlines a data science portfolio showcasing projects in data analysis, visualization, machine learning, recommendation systems, time series forecasting, deep learning, and natural language processing.'}, {'id': 1, 'name': 'my_Linkedin.pdf', 'description': 'This document outlines the experience of Abdelrahman Mohamed, an AI Engineer specializing in LLM agents, RAG pipelines, and real-time AI assistants, with roles at Electro Pi, Sand Technologies, and ALX Arabia.'}]
# [{'id': 0, 'name': 'projects_portfolio_in_github.pdf', 'description': 'This document outlines a data science portfolio showcasing projects in data analysis, visualization, machine learning, recommendation systems, time series forecasting, deep learning, and natural language processing.'}, {'id': 1, 'name': 'my_Linkedin.pdf', 'description': 'This document outlines the experience of Abdelrahman Mohamed, an AI Engineer specializing in LLM agents, RAG pipelines, and real-time AI assistants, with roles at Electro Pi, Sand Technologies, and ALX Arabia.'}, {'id': 2, 'name': 'Abdelrahman_Mohamed_CV_14.9_1.pdf', 'description': 'This document is a resume for Abdelrahman Mohamed, an AI/ML Engineer with experience in GenAI systems, LLM fine-tuning, RAG pipelines, and real-time voice assistants, with a focus on Arabic AI applications.'}]

# %%
docs_titles
# Out:
# [{'id': 0,
#   'name': 'projects_portfolio_in_github.pdf',
#   'description': 'This document outlines a data science portfolio showcasing projects in data analysis, visualization, machine learning, recommendation systems, time series forecasting, deep learning, and natural language processing.'},
#  {'id': 1,
#   'name': 'my_Linkedin.pdf',
#   'description': 'This document outlines the experience of Abdelrahman Mohamed, an AI Engineer specializing in LLM agents, RAG pipelines, and real-time AI assistants, with roles at Electro Pi, Sand Technologies, and ALX Arabia.'},
#  {'id': 2,
#   'name': 'Abdelrahman_Mohamed_CV_14.9_1.pdf',
#   'description': 'This document is a resume for Abdelrahman Mohamed, an AI/ML Engineer with experience in GenAI systems, LLM fine-tuning, RAG pipelines, and real-time voice assistants, with a focus on Arabic AI applications.'}]

# %% [markdown]
# ### get pdfs titles function

# %%
def get_tree_titles(pi_client: PageIndexClient) -> list[dict]:
    try:
        docs_list = pi_client.list_documents()

        docs_titles = [
            {
                "doc_index": i,
                "name": doc.get("name"),
                "description": doc.get("description")
            }
            for i, doc in enumerate(docs_list.get("documents", []))
        ]

        return docs_titles

    except Exception as e:
        logger.exception("Error while trying to get the tree titles")
        # return []

# %%
get_tree_titles(pi_client)
# Out:
# [{'doc_index': 0,
#   'name': 'projects_portfolio_in_github.pdf',
#   'description': 'This document outlines a data science portfolio showcasing projects in data analysis, visualization, machine learning, recommendation systems, time series forecasting, deep learning, and natural language processing.'},
#  {'doc_index': 1,
#   'name': 'my_Linkedin.pdf',
#   'description': 'This document outlines the experience of Abdelrahman Mohamed, an AI Engineer specializing in LLM agents, RAG pipelines, and real-time AI assistants, with roles at Electro Pi, Sand Technologies, and ALX Arabia.'},
#  {'doc_index': 2,
#   'name': 'Abdelrahman_Mohamed_CV_14.9_1.pdf',
#   'description': 'This document is a resume for Abdelrahman Mohamed, an AI/ML Engineer with experience in GenAI systems, LLM fine-tuning, RAG pipelines, and real-time voice assistants, with a focus on Arabic AI applications.'}]

# %%
# output = [doc_indexs]

# %% [markdown]
# # get docs TOC

# %%
doc_id  = docs_list["documents"][2]['id']

# %%
docs_list["documents"][2]
# Out:
# {'id': 'pi-cmnnmjcdr016q01qvn3cwv3ub',
#  'name': 'Abdelrahman_Mohamed_CV_14.9_1.pdf',
#  'description': 'This document is a resume for Abdelrahman Mohamed, an AI/ML Engineer with experience in GenAI systems, LLM fine-tuning, RAG pipelines, and real-time voice assistants, with a focus on Arabic AI applications.',
#  'status': 'completed',
#  'createdAt': '2026-04-06T20:09:39.983000',
#  'pageNum': 2,
#  'folderId': None}

# %%
tree_result =  pi_client.get_tree( doc_id, node_summary=True)

# pageindex_tree = tree_result.get("result" , [])

# %%
tree_result
# Out:
# {'doc_id': 'pi-cmnnmjcdr016q01qvn3cwv3ub',
#  'status': 'completed',
#  'retrieval_ready': True,
#  'result': [{'title': 'Abdelrahman Mohamed',
#    'node_id': '0000',
#    'page_index': 1,
#    'prefix_summary': '# Abdelrahman Mohamed\n',
#    'text': '# Abdelrahman Mohamed\n',
#    'nodes': [{'title': 'AI/ML Engineer',
#      'node_id': '0001',
#      'page_index': 1,
#      'prefix_summary': '## AI/ML Engineer\n\nabdelrahman.m2922@gmail.com  +201099394113  Cairo, Egypt  abdelrahman-ai\n\nGitHub  Medium\n',
#      'text': '## AI/ML Engineer\n\nabdelrahman.m2922@gmail.com  +201099394113  Cairo, Egypt  abdelrahman-ai\n\nGitHub  Medium\n',
#      'nodes': [{'title': 'PROFESSIONAL SUMMARY',
#        'node_id': '0002',
#        'page_index': 1,
#        'summary': '### PROFESSIONAL SUMMARY\n\nAI Engineer experienced in real-world GenAI systems, from LLM fine-tuning and agentic workflows to RAG pipelines and real-time voice assistants. Strong ML and Python foundation, with a deep interest in advancing Arabic AI applications.\n',
#        'text': '### PROFESSIONAL SUMMARY\n\nAI Engineer experienced in real-world GenAI systems, from LLM fine-tuning and agentic workflows to RAG pipelines and real-time voice assistants. Strong ML and Python foundation, with a deep interest in advancing Arabic AI applications.\n'},
#       {'title': 'PROFESSIONAL EXPERIENCE',
#        'node_id': '0003',
#        'page_index': 1,
#        'summary': '### PROFESSIONAL EXPERIENCE\n',
#        'text': '### PROFESSIONAL EXPERIENCE\n'},
#       {'title': 'EDUCATION',
#        'node_id': '0004',
#        'page_index': 1,
#        'prefix_summary': '### EDUCATION\n',
#        'text': '### EDUCATION\n',
#        'nodes': [{'title': 'ALX Africa – ExploreAI Academy,',
#          'node_id': '0005',
#          'page_index': 1,
#          'summary': '#### ALX Africa – ExploreAI Academy,\n\n05/2023 – 09/2024 | Cairo, Egypt\n\n**Scholarship in Data Science, 13-Month Program**\n\n- Included: 2 months of soft skills training and 11 months of data science studies in collaboration with ExploreAI Academy.\n- Covers: Excel, SQL, Power BI, Python, Machine Learning (ML), NLP, AWS Foundations.\n',
#          'text': '#### ALX Africa – ExploreAI Academy,\n\n05/2023 – 09/2024 | Cairo, Egypt\n\n**Scholarship in Data Science, 13-Month Program**\n\n- Included: 2 months of soft skills training and 11 months of data science studies in collaboration with ExploreAI Academy.\n- Covers: Excel, SQL, Power BI, Python, Machine Learning (ML), NLP, AWS Foundations.\n'},
#         {'title': 'Canadian International College (CIC),',
#          'node_id': '0006',
#          'page_index': 1,
#          'summary': '#### Canadian International College (CIC),\n\n09/2018 – 06/2023 | Cairo, Egypt\n\n**B.Sc in Electronics and Communication Engineering**\n\n- GPA: **3.52** | Rank: **3rd**\n- Graduation project: Web Application Firewall-based ML and NLP | Grade: **A+** | **Paper**  | **code**\n\nPROJECTS\n',
#          'text': '#### Canadian International College (CIC),\n\n09/2018 – 06/2023 | Cairo, Egypt\n\n**B.Sc in Electronics and Communication Engineering**\n\n- GPA: **3.52** | Rank: **3rd**\n- Graduation project: Web Application Firewall-based ML and NLP | Grade: **A+** | **Paper**  | **code**\n\nPROJECTS\n'},
#         {'title': 'Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory',
#          'node_id': '0007',
#          'page_index': 2,
#          'summary': '#### Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory\n\n- Translated business requirements into technical specifications, leading the team (UI/UX, Frontend, AI, QA/Test) and designing the agent and system architecture during the POC phase.\n- Implemented a LangGraph-based agent orchestration layer supporting text, voice, and visual (infographic) modalities across retrieval and response generation.\n- Built RAG pipelines using a vector database to ingest and retrieve domain-specific research content, balancing relevance, latency, and cost.\n- Added LLM observability and monitoring with LangSmith to track token usage, latency, and answers.\n',
#          'text': '#### Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory\n\n- Translated business requirements into technical specifications, leading the team (UI/UX, Frontend, AI, QA/Test) and designing the agent and system architecture during the POC phase.\n- Implemented a LangGraph-based agent orchestration layer supporting text, voice, and visual (infographic) modalities across retrieval and response generation.\n- Built RAG pipelines using a vector database to ingest and retrieve domain-specific research content, balancing relevance, latency, and cost.\n- Added LLM observability and monitoring with LangSmith to track token usage, latency, and answers.\n'},
#         {'title': 'Contract Analysis Agent based on Sharia and Law',
#          'node_id': '0008',
#          'page_index': 2,
#          'summary': '#### Contract Analysis Agent based on Sharia and Law\n\n- Developed a LangGraph RAG system with 5 concurrent nodes, cutting response time by ~80%.\n- Processed 32+ clauses/batch using async parallelism.\n- Delivered 10+ FastAPI endpoints for classification, scoring, and digitalization.\n\nTech Stack: Python, FastAPI, LangGraph, Reranking, Docker\n',
#          'text': '#### Contract Analysis Agent based on Sharia and Law\n\n- Developed a LangGraph RAG system with 5 concurrent nodes, cutting response time by ~80%.\n- Processed 32+ clauses/batch using async parallelism.\n- Delivered 10+ FastAPI endpoints for classification, scoring, and digitalization.\n\nTech Stack: Python, FastAPI, LangGraph, Reranking, Docker\n'},
#         {'title': 'Virtual CFO Agent',
#          'node_id': '0009',
#          'page_index': 2,
#          'summary': '#### Virtual CFO Agent\n\n- Built a multi-LLM financial reasoning workflow (6 interconnected models)\n- Implemented RAG for external knowledge and optimized pipelines, reducing latency by 83%.\n- Tech Stack: Python, LangChain, MySQL, PostgreSQL, MongoDB, Hugging Face, Docker\n',
#          'text': '#### Virtual CFO Agent\n\n- Built a multi-LLM financial reasoning workflow (6 interconnected models)\n- Implemented RAG for external knowledge and optimized pipelines, reducing latency by 83%.\n- Tech Stack: Python, LangChain, MySQL, PostgreSQL, MongoDB, Hugging Face, Docker\n'},
#         {'title': 'Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)',
#          'node_id': '0010',
#          'page_index': 2,
#          'summary': '#### Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)\n\n- Collected Saudi Arabic dialect speech data from YouTube and extracted transcripts using Whisper\n- Optimized inference using mixed precision (FP16), achieving RTF ≈ 0.35, on a 4GB VRAM\n- Deployed the model using vLLM with dynamic batching (batch size = 45), utilizing 23GB VRAM to achieve ~2-second latency and a throughput of 5 requests per second (RPS).\n',
#          'text': '#### Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)\n\n- Collected Saudi Arabic dialect speech data from YouTube and extracted transcripts using Whisper\n- Optimized inference using mixed precision (FP16), achieving RTF ≈ 0.35, on a 4GB VRAM\n- Deployed the model using vLLM with dynamic batching (batch size = 45), utilizing 23GB VRAM to achieve ~2-second latency and a throughput of 5 requests per second (RPS).\n'}]},
#       {'title': 'SKILLS',
#        'node_id': '0011',
#        'page_index': 2,
#        'summary': '### SKILLS\n\nML/AI Frameworks — TensorFlow | PyTorch | Scikit-learn | Hugging Face | Transformers | LangChain | LangGraph | PEFT | BitsAndBytes | Unsloth | Ollama | vLLM\n\nNLP/GenAI — spaCy | NLTK | RAG | OpenAI | Gemini | Open-source LLMs | Embeddings\n\nDatabases — PostgreSQL | MySQL | MongoDB | Qdrant | FAISS | Chroma\n\nCloud &amp; DevOps — AWS | GCP | Docker | GitHub Actions\n\nAPIs &amp; Frameworks — FastAPI | Flask | Streamli | Gradio\n\nData Analysis — Pandas | NumPy | Matplotlib | Plotly | Power BI\n\nOther Tools — Prometheus | Grafana | Git/GitHub | Linux | Pytest | LiveKit | Pydantic | LangSmith\n',
#        'text': '### SKILLS\n\nML/AI Frameworks — TensorFlow | PyTorch | Scikit-learn | Hugging Face | Transformers | LangChain | LangGraph | PEFT | BitsAndBytes | Unsloth | Ollama | vLLM\n\nNLP/GenAI — spaCy | NLTK | RAG | OpenAI | Gemini | Open-source LLMs | Embeddings\n\nDatabases — PostgreSQL | MySQL | MongoDB | Qdrant | FAISS | Chroma\n\nCloud &amp; DevOps — AWS | GCP | Docker | GitHub Actions\n\nAPIs &amp; Frameworks — FastAPI | Flask | Streamli | Gradio\n\nData Analysis — Pandas | NumPy | Matplotlib | Plotly | Power BI\n\nOther Tools — Prometheus | Grafana | Git/GitHub | Linux | Pytest | LiveKit | Pydantic | LangSmith\n'},
#       {'title': 'VOLUNTEERING',
#        'node_id': '0012',
#        'page_index': 2,
#        'summary': '### VOLUNTEERING\n\nMember, AI Team - CIC Radix Team, Atlantis Underwater Robotics, ROV Competition\n\n- Built AI algorithms for underwater coral reef detection and plastic waste removal.\n',
#        'text': '### VOLUNTEERING\n\nMember, AI Team - CIC Radix Team, Atlantis Underwater Robotics, ROV Competition\n\n- Built AI algorithms for underwater coral reef detection and plastic waste removal.\n'}]}]}]}

# %%
tree =tree_result.get("result" , [])

# %%
len(tree)
# Out:
# 1

# %%
tree
# Out:
# [{'title': 'Abdelrahman Mohamed',
#   'node_id': '0000',
#   'page_index': 1,
#   'prefix_summary': '# Abdelrahman Mohamed\n',
#   'text': '# Abdelrahman Mohamed\n',
#   'nodes': [{'title': 'AI/ML Engineer',
#     'node_id': '0001',
#     'page_index': 1,
#     'prefix_summary': '## AI/ML Engineer\n\nabdelrahman.m2922@gmail.com  +201099394113  Cairo, Egypt  abdelrahman-ai\n\nGitHub  Medium\n',
#     'text': '## AI/ML Engineer\n\nabdelrahman.m2922@gmail.com  +201099394113  Cairo, Egypt  abdelrahman-ai\n\nGitHub  Medium\n',
#     'nodes': [{'title': 'PROFESSIONAL SUMMARY',
#       'node_id': '0002',
#       'page_index': 1,
#       'summary': '### PROFESSIONAL SUMMARY\n\nAI Engineer experienced in real-world GenAI systems, from LLM fine-tuning and agentic workflows to RAG pipelines and real-time voice assistants. Strong ML and Python foundation, with a deep interest in advancing Arabic AI applications.\n',
#       'text': '### PROFESSIONAL SUMMARY\n\nAI Engineer experienced in real-world GenAI systems, from LLM fine-tuning and agentic workflows to RAG pipelines and real-time voice assistants. Strong ML and Python foundation, with a deep interest in advancing Arabic AI applications.\n'},
#      {'title': 'PROFESSIONAL EXPERIENCE',
#       'node_id': '0003',
#       'page_index': 1,
#       'summary': '### PROFESSIONAL EXPERIENCE\n',
#       'text': '### PROFESSIONAL EXPERIENCE\n'},
#      {'title': 'EDUCATION',
#       'node_id': '0004',
#       'page_index': 1,
#       'prefix_summary': '### EDUCATION\n',
#       'text': '### EDUCATION\n',
#       'nodes': [{'title': 'ALX Africa – ExploreAI Academy,',
#         'node_id': '0005',
#         'page_index': 1,
#         'summary': '#### ALX Africa – ExploreAI Academy,\n\n05/2023 – 09/2024 | Cairo, Egypt\n\n**Scholarship in Data Science, 13-Month Program**\n\n- Included: 2 months of soft skills training and 11 months of data science studies in collaboration with ExploreAI Academy.\n- Covers: Excel, SQL, Power BI, Python, Machine Learning (ML), NLP, AWS Foundations.\n',
#         'text': '#### ALX Africa – ExploreAI Academy,\n\n05/2023 – 09/2024 | Cairo, Egypt\n\n**Scholarship in Data Science, 13-Month Program**\n\n- Included: 2 months of soft skills training and 11 months of data science studies in collaboration with ExploreAI Academy.\n- Covers: Excel, SQL, Power BI, Python, Machine Learning (ML), NLP, AWS Foundations.\n'},
#        {'title': 'Canadian International College (CIC),',
#         'node_id': '0006',
#         'page_index': 1,
#         'summary': '#### Canadian International College (CIC),\n\n09/2018 – 06/2023 | Cairo, Egypt\n\n**B.Sc in Electronics and Communication Engineering**\n\n- GPA: **3.52** | Rank: **3rd**\n- Graduation project: Web Application Firewall-based ML and NLP | Grade: **A+** | **Paper**  | **code**\n\nPROJECTS\n',
#         'text': '#### Canadian International College (CIC),\n\n09/2018 – 06/2023 | Cairo, Egypt\n\n**B.Sc in Electronics and Communication Engineering**\n\n- GPA: **3.52** | Rank: **3rd**\n- Graduation project: Web Application Firewall-based ML and NLP | Grade: **A+** | **Paper**  | **code**\n\nPROJECTS\n'},
#        {'title': 'Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory',
#         'node_id': '0007',
#         'page_index': 2,
#         'summary': '#### Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory\n\n- Translated business requirements into technical specifications, leading the team (UI/UX, Frontend, AI, QA/Test) and designing the agent and system architecture during the POC phase.\n- Implemented a LangGraph-based agent orchestration layer supporting text, voice, and visual (infographic) modalities across retrieval and response generation.\n- Built RAG pipelines using a vector database to ingest and retrieve domain-specific research content, balancing relevance, latency, and cost.\n- Added LLM observability and monitoring with LangSmith to track token usage, latency, and answers.\n',
#         'text': '#### Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory\n\n- Translated business requirements into technical specifications, leading the team (UI/UX, Frontend, AI, QA/Test) and designing the agent and system architecture during the POC phase.\n- Implemented a LangGraph-based agent orchestration layer supporting text, voice, and visual (infographic) modalities across retrieval and response generation.\n- Built RAG pipelines using a vector database to ingest and retrieve domain-specific research content, balancing relevance, latency, and cost.\n- Added LLM observability and monitoring with LangSmith to track token usage, latency, and answers.\n'},
#        {'title': 'Contract Analysis Agent based on Sharia and Law',
#         'node_id': '0008',
#         'page_index': 2,
#         'summary': '#### Contract Analysis Agent based on Sharia and Law\n\n- Developed a LangGraph RAG system with 5 concurrent nodes, cutting response time by ~80%.\n- Processed 32+ clauses/batch using async parallelism.\n- Delivered 10+ FastAPI endpoints for classification, scoring, and digitalization.\n\nTech Stack: Python, FastAPI, LangGraph, Reranking, Docker\n',
#         'text': '#### Contract Analysis Agent based on Sharia and Law\n\n- Developed a LangGraph RAG system with 5 concurrent nodes, cutting response time by ~80%.\n- Processed 32+ clauses/batch using async parallelism.\n- Delivered 10+ FastAPI endpoints for classification, scoring, and digitalization.\n\nTech Stack: Python, FastAPI, LangGraph, Reranking, Docker\n'},
#        {'title': 'Virtual CFO Agent',
#         'node_id': '0009',
#         'page_index': 2,
#         'summary': '#### Virtual CFO Agent\n\n- Built a multi-LLM financial reasoning workflow (6 interconnected models)\n- Implemented RAG for external knowledge and optimized pipelines, reducing latency by 83%.\n- Tech Stack: Python, LangChain, MySQL, PostgreSQL, MongoDB, Hugging Face, Docker\n',
#         'text': '#### Virtual CFO Agent\n\n- Built a multi-LLM financial reasoning workflow (6 interconnected models)\n- Implemented RAG for external knowledge and optimized pipelines, reducing latency by 83%.\n- Tech Stack: Python, LangChain, MySQL, PostgreSQL, MongoDB, Hugging Face, Docker\n'},
#        {'title': 'Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)',
#         'node_id': '0010',
#         'page_index': 2,
#         'summary': '#### Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)\n\n- Collected Saudi Arabic dialect speech data from YouTube and extracted transcripts using Whisper\n- Optimized inference using mixed precision (FP16), achieving RTF ≈ 0.35, on a 4GB VRAM\n- Deployed the model using vLLM with dynamic batching (batch size = 45), utilizing 23GB VRAM to achieve ~2-second latency and a throughput of 5 requests per second (RPS).\n',
#         'text': '#### Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)\n\n- Collected Saudi Arabic dialect speech data from YouTube and extracted transcripts using Whisper\n- Optimized inference using mixed precision (FP16), achieving RTF ≈ 0.35, on a 4GB VRAM\n- Deployed the model using vLLM with dynamic batching (batch size = 45), utilizing 23GB VRAM to achieve ~2-second latency and a throughput of 5 requests per second (RPS).\n'}]},
#      {'title': 'SKILLS',
#       'node_id': '0011',
#       'page_index': 2,
#       'summary': '### SKILLS\n\nML/AI Frameworks — TensorFlow | PyTorch | Scikit-learn | Hugging Face | Transformers | LangChain | LangGraph | PEFT | BitsAndBytes | Unsloth | Ollama | vLLM\n\nNLP/GenAI — spaCy | NLTK | RAG | OpenAI | Gemini | Open-source LLMs | Embeddings\n\nDatabases — PostgreSQL | MySQL | MongoDB | Qdrant | FAISS | Chroma\n\nCloud &amp; DevOps — AWS | GCP | Docker | GitHub Actions\n\nAPIs &amp; Frameworks — FastAPI | Flask | Streamli | Gradio\n\nData Analysis — Pandas | NumPy | Matplotlib | Plotly | Power BI\n\nOther Tools — Prometheus | Grafana | Git/GitHub | Linux | Pytest | LiveKit | Pydantic | LangSmith\n',
#       'text': '### SKILLS\n\nML/AI Frameworks — TensorFlow | PyTorch | Scikit-learn | Hugging Face | Transformers | LangChain | LangGraph | PEFT | BitsAndBytes | Unsloth | Ollama | vLLM\n\nNLP/GenAI — spaCy | NLTK | RAG | OpenAI | Gemini | Open-source LLMs | Embeddings\n\nDatabases — PostgreSQL | MySQL | MongoDB | Qdrant | FAISS | Chroma\n\nCloud &amp; DevOps — AWS | GCP | Docker | GitHub Actions\n\nAPIs &amp; Frameworks — FastAPI | Flask | Streamli | Gradio\n\nData Analysis — Pandas | NumPy | Matplotlib | Plotly | Power BI\n\nOther Tools — Prometheus | Grafana | Git/GitHub | Linux | Pytest | LiveKit | Pydantic | LangSmith\n'},
#      {'title': 'VOLUNTEERING',
#       'node_id': '0012',
#       'page_index': 2,
#       'summary': '### VOLUNTEERING\n\nMember, AI Team - CIC Radix Team, Atlantis Underwater Robotics, ROV Competition\n\n- Built AI algorithms for underwater coral reef detection and plastic waste removal.\n',
#       'text': '### VOLUNTEERING\n\nMember, AI Team - CIC Radix Team, Atlantis Underwater Robotics, ROV Competition\n\n- Built AI algorithms for underwater coral reef detection and plastic waste removal.\n'}]}]}]

# %%
tree[0]
# Out:
# {'title': 'Abdelrahman Mohamed',
#  'node_id': '0000',
#  'page_index': 1,
#  'prefix_summary': '# Abdelrahman Mohamed\n',
#  'text': '# Abdelrahman Mohamed\n',
#  'nodes': [{'title': 'AI/ML Engineer',
#    'node_id': '0001',
#    'page_index': 1,
#    'prefix_summary': '## AI/ML Engineer\n\nabdelrahman.m2922@gmail.com  +201099394113  Cairo, Egypt  abdelrahman-ai\n\nGitHub  Medium\n',
#    'text': '## AI/ML Engineer\n\nabdelrahman.m2922@gmail.com  +201099394113  Cairo, Egypt  abdelrahman-ai\n\nGitHub  Medium\n',
#    'nodes': [{'title': 'PROFESSIONAL SUMMARY',
#      'node_id': '0002',
#      'page_index': 1,
#      'summary': '### PROFESSIONAL SUMMARY\n\nAI Engineer experienced in real-world GenAI systems, from LLM fine-tuning and agentic workflows to RAG pipelines and real-time voice assistants. Strong ML and Python foundation, with a deep interest in advancing Arabic AI applications.\n',
#      'text': '### PROFESSIONAL SUMMARY\n\nAI Engineer experienced in real-world GenAI systems, from LLM fine-tuning and agentic workflows to RAG pipelines and real-time voice assistants. Strong ML and Python foundation, with a deep interest in advancing Arabic AI applications.\n'},
#     {'title': 'PROFESSIONAL EXPERIENCE',
#      'node_id': '0003',
#      'page_index': 1,
#      'summary': '### PROFESSIONAL EXPERIENCE\n',
#      'text': '### PROFESSIONAL EXPERIENCE\n'},
#     {'title': 'EDUCATION',
#      'node_id': '0004',
#      'page_index': 1,
#      'prefix_summary': '### EDUCATION\n',
#      'text': '### EDUCATION\n',
#      'nodes': [{'title': 'ALX Africa – ExploreAI Academy,',
#        'node_id': '0005',
#        'page_index': 1,
#        'summary': '#### ALX Africa – ExploreAI Academy,\n\n05/2023 – 09/2024 | Cairo, Egypt\n\n**Scholarship in Data Science, 13-Month Program**\n\n- Included: 2 months of soft skills training and 11 months of data science studies in collaboration with ExploreAI Academy.\n- Covers: Excel, SQL, Power BI, Python, Machine Learning (ML), NLP, AWS Foundations.\n',
#        'text': '#### ALX Africa – ExploreAI Academy,\n\n05/2023 – 09/2024 | Cairo, Egypt\n\n**Scholarship in Data Science, 13-Month Program**\n\n- Included: 2 months of soft skills training and 11 months of data science studies in collaboration with ExploreAI Academy.\n- Covers: Excel, SQL, Power BI, Python, Machine Learning (ML), NLP, AWS Foundations.\n'},
#       {'title': 'Canadian International College (CIC),',
#        'node_id': '0006',
#        'page_index': 1,
#        'summary': '#### Canadian International College (CIC),\n\n09/2018 – 06/2023 | Cairo, Egypt\n\n**B.Sc in Electronics and Communication Engineering**\n\n- GPA: **3.52** | Rank: **3rd**\n- Graduation project: Web Application Firewall-based ML and NLP | Grade: **A+** | **Paper**  | **code**\n\nPROJECTS\n',
#        'text': '#### Canadian International College (CIC),\n\n09/2018 – 06/2023 | Cairo, Egypt\n\n**B.Sc in Electronics and Communication Engineering**\n\n- GPA: **3.52** | Rank: **3rd**\n- Graduation project: Web Application Firewall-based ML and NLP | Grade: **A+** | **Paper**  | **code**\n\nPROJECTS\n'},
#       {'title': 'Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory',
#        'node_id': '0007',
#        'page_index': 2,
#        'summary': '#### Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory\n\n- Translated business requirements into technical specifications, leading the team (UI/UX, Frontend, AI, QA/Test) and designing the agent and system architecture during the POC phase.\n- Implemented a LangGraph-based agent orchestration layer supporting text, voice, and visual (infographic) modalities across retrieval and response generation.\n- Built RAG pipelines using a vector database to ingest and retrieve domain-specific research content, balancing relevance, latency, and cost.\n- Added LLM observability and monitoring with LangSmith to track token usage, latency, and answers.\n',
#        'text': '#### Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory\n\n- Translated business requirements into technical specifications, leading the team (UI/UX, Frontend, AI, QA/Test) and designing the agent and system architecture during the POC phase.\n- Implemented a LangGraph-based agent orchestration layer supporting text, voice, and visual (infographic) modalities across retrieval and response generation.\n- Built RAG pipelines using a vector database to ingest and retrieve domain-specific research content, balancing relevance, latency, and cost.\n- Added LLM observability and monitoring with LangSmith to track token usage, latency, and answers.\n'},
#       {'title': 'Contract Analysis Agent based on Sharia and Law',
#        'node_id': '0008',
#        'page_index': 2,
#        'summary': '#### Contract Analysis Agent based on Sharia and Law\n\n- Developed a LangGraph RAG system with 5 concurrent nodes, cutting response time by ~80%.\n- Processed 32+ clauses/batch using async parallelism.\n- Delivered 10+ FastAPI endpoints for classification, scoring, and digitalization.\n\nTech Stack: Python, FastAPI, LangGraph, Reranking, Docker\n',
#        'text': '#### Contract Analysis Agent based on Sharia and Law\n\n- Developed a LangGraph RAG system with 5 concurrent nodes, cutting response time by ~80%.\n- Processed 32+ clauses/batch using async parallelism.\n- Delivered 10+ FastAPI endpoints for classification, scoring, and digitalization.\n\nTech Stack: Python, FastAPI, LangGraph, Reranking, Docker\n'},
#       {'title': 'Virtual CFO Agent',
#        'node_id': '0009',
#        'page_index': 2,
#        'summary': '#### Virtual CFO Agent\n\n- Built a multi-LLM financial reasoning workflow (6 interconnected models)\n- Implemented RAG for external knowledge and optimized pipelines, reducing latency by 83%.\n- Tech Stack: Python, LangChain, MySQL, PostgreSQL, MongoDB, Hugging Face, Docker\n',
#        'text': '#### Virtual CFO Agent\n\n- Built a multi-LLM financial reasoning workflow (6 interconnected models)\n- Implemented RAG for external knowledge and optimized pipelines, reducing latency by 83%.\n- Tech Stack: Python, LangChain, MySQL, PostgreSQL, MongoDB, Hugging Face, Docker\n'},
#       {'title': 'Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)',
#        'node_id': '0010',
#        'page_index': 2,
#        'summary': '#### Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)\n\n- Collected Saudi Arabic dialect speech data from YouTube and extracted transcripts using Whisper\n- Optimized inference using mixed precision (FP16), achieving RTF ≈ 0.35, on a 4GB VRAM\n- Deployed the model using vLLM with dynamic batching (batch size = 45), utilizing 23GB VRAM to achieve ~2-second latency and a throughput of 5 requests per second (RPS).\n',
#        'text': '#### Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)\n\n- Collected Saudi Arabic dialect speech data from YouTube and extracted transcripts using Whisper\n- Optimized inference using mixed precision (FP16), achieving RTF ≈ 0.35, on a 4GB VRAM\n- Deployed the model using vLLM with dynamic batching (batch size = 45), utilizing 23GB VRAM to achieve ~2-second latency and a throughput of 5 requests per second (RPS).\n'}]},
#     {'title': 'SKILLS',
#      'node_id': '0011',
#      'page_index': 2,
#      'summary': '### SKILLS\n\nML/AI Frameworks — TensorFlow | PyTorch | Scikit-learn | Hugging Face | Transformers | LangChain | LangGraph | PEFT | BitsAndBytes | Unsloth | Ollama | vLLM\n\nNLP/GenAI — spaCy | NLTK | RAG | OpenAI | Gemini | Open-source LLMs | Embeddings\n\nDatabases — PostgreSQL | MySQL | MongoDB | Qdrant | FAISS | Chroma\n\nCloud &amp; DevOps — AWS | GCP | Docker | GitHub Actions\n\nAPIs &amp; Frameworks — FastAPI | Flask | Streamli | Gradio\n\nData Analysis — Pandas | NumPy | Matplotlib | Plotly | Power BI\n\nOther Tools — Prometheus | Grafana | Git/GitHub | Linux | Pytest | LiveKit | Pydantic | LangSmith\n',
#      'text': '### SKILLS\n\nML/AI Frameworks — TensorFlow | PyTorch | Scikit-learn | Hugging Face | Transformers | LangChain | LangGraph | PEFT | BitsAndBytes | Unsloth | Ollama | vLLM\n\nNLP/GenAI — spaCy | NLTK | RAG | OpenAI | Gemini | Open-source LLMs | Embeddings\n\nDatabases — PostgreSQL | MySQL | MongoDB | Qdrant | FAISS | Chroma\n\nCloud &amp; DevOps — AWS | GCP | Docker | GitHub Actions\n\nAPIs &amp; Frameworks — FastAPI | Flask | Streamli | Gradio\n\nData Analysis — Pandas | NumPy | Matplotlib | Plotly | Power BI\n\nOther Tools — Prometheus | Grafana | Git/GitHub | Linux | Pytest | LiveKit | Pydantic | LangSmith\n'},
#     {'title': 'VOLUNTEERING',
#      'node_id': '0012',
#      'page_index': 2,
#      'summary': '### VOLUNTEERING\n\nMember, AI Team - CIC Radix Team, Atlantis Underwater Robotics, ROV Competition\n\n- Built AI algorithms for underwater coral reef detection and plastic waste removal.\n',
#      'text': '### VOLUNTEERING\n\nMember, AI Team - CIC Radix Team, Atlantis Underwater Robotics, ROV Competition\n\n- Built AI algorithms for underwater coral reef detection and plastic waste removal.\n'}]}]}

# %%
tree[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 tree[1]
#
# IndexError: list index out of range

# %%
[{
    "node_id":"",
    "title" : "",
    "node_summary":"",
    "child_nodes": []
}]
# Out:
# [{'node_id': '', 'title': '', 'node_summary': '', 'child_nodes': []}]

# %%
tree[0]
# Out:
# {'title': 'Abdelrahman Mohamed',
#  'node_id': '0000',
#  'page_index': 1,
#  'prefix_summary': '# Abdelrahman Mohamed\n',
#  'text': '# Abdelrahman Mohamed\n',
#  'nodes': [{'title': 'AI/ML Engineer',
#    'node_id': '0001',
#    'page_index': 1,
#    'prefix_summary': '## AI/ML Engineer\n\nabdelrahman.m2922@gmail.com  +201099394113  Cairo, Egypt  abdelrahman-ai\n\nGitHub  Medium\n',
#    'text': '## AI/ML Engineer\n\nabdelrahman.m2922@gmail.com  +201099394113  Cairo, Egypt  abdelrahman-ai\n\nGitHub  Medium\n',
#    'nodes': [{'title': 'PROFESSIONAL SUMMARY',
#      'node_id': '0002',
#      'page_index': 1,
#      'summary': '### PROFESSIONAL SUMMARY\n\nAI Engineer experienced in real-world GenAI systems, from LLM fine-tuning and agentic workflows to RAG pipelines and real-time voice assistants. Strong ML and Python foundation, with a deep interest in advancing Arabic AI applications.\n',
#      'text': '### PROFESSIONAL SUMMARY\n\nAI Engineer experienced in real-world GenAI systems, from LLM fine-tuning and agentic workflows to RAG pipelines and real-time voice assistants. Strong ML and Python foundation, with a deep interest in advancing Arabic AI applications.\n'},
#     {'title': 'PROFESSIONAL EXPERIENCE',
#      'node_id': '0003',
#      'page_index': 1,
#      'summary': '### PROFESSIONAL EXPERIENCE\n',
#      'text': '### PROFESSIONAL EXPERIENCE\n'},
#     {'title': 'EDUCATION',
#      'node_id': '0004',
#      'page_index': 1,
#      'prefix_summary': '### EDUCATION\n',
#      'text': '### EDUCATION\n',
#      'nodes': [{'title': 'ALX Africa – ExploreAI Academy,',
#        'node_id': '0005',
#        'page_index': 1,
#        'summary': '#### ALX Africa – ExploreAI Academy,\n\n05/2023 – 09/2024 | Cairo, Egypt\n\n**Scholarship in Data Science, 13-Month Program**\n\n- Included: 2 months of soft skills training and 11 months of data science studies in collaboration with ExploreAI Academy.\n- Covers: Excel, SQL, Power BI, Python, Machine Learning (ML), NLP, AWS Foundations.\n',
#        'text': '#### ALX Africa – ExploreAI Academy,\n\n05/2023 – 09/2024 | Cairo, Egypt\n\n**Scholarship in Data Science, 13-Month Program**\n\n- Included: 2 months of soft skills training and 11 months of data science studies in collaboration with ExploreAI Academy.\n- Covers: Excel, SQL, Power BI, Python, Machine Learning (ML), NLP, AWS Foundations.\n'},
#       {'title': 'Canadian International College (CIC),',
#        'node_id': '0006',
#        'page_index': 1,
#        'summary': '#### Canadian International College (CIC),\n\n09/2018 – 06/2023 | Cairo, Egypt\n\n**B.Sc in Electronics and Communication Engineering**\n\n- GPA: **3.52** | Rank: **3rd**\n- Graduation project: Web Application Firewall-based ML and NLP | Grade: **A+** | **Paper**  | **code**\n\nPROJECTS\n',
#        'text': '#### Canadian International College (CIC),\n\n09/2018 – 06/2023 | Cairo, Egypt\n\n**B.Sc in Electronics and Communication Engineering**\n\n- GPA: **3.52** | Rank: **3rd**\n- Graduation project: Web Application Firewall-based ML and NLP | Grade: **A+** | **Paper**  | **code**\n\nPROJECTS\n'},
#       {'title': 'Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory',
#        'node_id': '0007',
#        'page_index': 2,
#        'summary': '#### Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory\n\n- Translated business requirements into technical specifications, leading the team (UI/UX, Frontend, AI, QA/Test) and designing the agent and system architecture during the POC phase.\n- Implemented a LangGraph-based agent orchestration layer supporting text, voice, and visual (infographic) modalities across retrieval and response generation.\n- Built RAG pipelines using a vector database to ingest and retrieve domain-specific research content, balancing relevance, latency, and cost.\n- Added LLM observability and monitoring with LangSmith to track token usage, latency, and answers.\n',
#        'text': '#### Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory\n\n- Translated business requirements into technical specifications, leading the team (UI/UX, Frontend, AI, QA/Test) and designing the agent and system architecture during the POC phase.\n- Implemented a LangGraph-based agent orchestration layer supporting text, voice, and visual (infographic) modalities across retrieval and response generation.\n- Built RAG pipelines using a vector database to ingest and retrieve domain-specific research content, balancing relevance, latency, and cost.\n- Added LLM observability and monitoring with LangSmith to track token usage, latency, and answers.\n'},
#       {'title': 'Contract Analysis Agent based on Sharia and Law',
#        'node_id': '0008',
#        'page_index': 2,
#        'summary': '#### Contract Analysis Agent based on Sharia and Law\n\n- Developed a LangGraph RAG system with 5 concurrent nodes, cutting response time by ~80%.\n- Processed 32+ clauses/batch using async parallelism.\n- Delivered 10+ FastAPI endpoints for classification, scoring, and digitalization.\n\nTech Stack: Python, FastAPI, LangGraph, Reranking, Docker\n',
#        'text': '#### Contract Analysis Agent based on Sharia and Law\n\n- Developed a LangGraph RAG system with 5 concurrent nodes, cutting response time by ~80%.\n- Processed 32+ clauses/batch using async parallelism.\n- Delivered 10+ FastAPI endpoints for classification, scoring, and digitalization.\n\nTech Stack: Python, FastAPI, LangGraph, Reranking, Docker\n'},
#       {'title': 'Virtual CFO Agent',
#        'node_id': '0009',
#        'page_index': 2,
#        'summary': '#### Virtual CFO Agent\n\n- Built a multi-LLM financial reasoning workflow (6 interconnected models)\n- Implemented RAG for external knowledge and optimized pipelines, reducing latency by 83%.\n- Tech Stack: Python, LangChain, MySQL, PostgreSQL, MongoDB, Hugging Face, Docker\n',
#        'text': '#### Virtual CFO Agent\n\n- Built a multi-LLM financial reasoning workflow (6 interconnected models)\n- Implemented RAG for external knowledge and optimized pipelines, reducing latency by 83%.\n- Tech Stack: Python, LangChain, MySQL, PostgreSQL, MongoDB, Hugging Face, Docker\n'},
#       {'title': 'Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)',
#        'node_id': '0010',
#        'page_index': 2,
#        'summary': '#### Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)\n\n- Collected Saudi Arabic dialect speech data from YouTube and extracted transcripts using Whisper\n- Optimized inference using mixed precision (FP16), achieving RTF ≈ 0.35, on a 4GB VRAM\n- Deployed the model using vLLM with dynamic batching (batch size = 45), utilizing 23GB VRAM to achieve ~2-second latency and a throughput of 5 requests per second (RPS).\n',
#        'text': '#### Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)\n\n- Collected Saudi Arabic dialect speech data from YouTube and extracted transcripts using Whisper\n- Optimized inference using mixed precision (FP16), achieving RTF ≈ 0.35, on a 4GB VRAM\n- Deployed the model using vLLM with dynamic batching (batch size = 45), utilizing 23GB VRAM to achieve ~2-second latency and a throughput of 5 requests per second (RPS).\n'}]},
#     {'title': 'SKILLS',
#      'node_id': '0011',
#      'page_index': 2,
#      'summary': '### SKILLS\n\nML/AI Frameworks — TensorFlow | PyTorch | Scikit-learn | Hugging Face | Transformers | LangChain | LangGraph | PEFT | BitsAndBytes | Unsloth | Ollama | vLLM\n\nNLP/GenAI — spaCy | NLTK | RAG | OpenAI | Gemini | Open-source LLMs | Embeddings\n\nDatabases — PostgreSQL | MySQL | MongoDB | Qdrant | FAISS | Chroma\n\nCloud &amp; DevOps — AWS | GCP | Docker | GitHub Actions\n\nAPIs &amp; Frameworks — FastAPI | Flask | Streamli | Gradio\n\nData Analysis — Pandas | NumPy | Matplotlib | Plotly | Power BI\n\nOther Tools — Prometheus | Grafana | Git/GitHub | Linux | Pytest | LiveKit | Pydantic | LangSmith\n',
#      'text': '### SKILLS\n\nML/AI Frameworks — TensorFlow | PyTorch | Scikit-learn | Hugging Face | Transformers | LangChain | LangGraph | PEFT | BitsAndBytes | Unsloth | Ollama | vLLM\n\nNLP/GenAI — spaCy | NLTK | RAG | OpenAI | Gemini | Open-source LLMs | Embeddings\n\nDatabases — PostgreSQL | MySQL | MongoDB | Qdrant | FAISS | Chroma\n\nCloud &amp; DevOps — AWS | GCP | Docker | GitHub Actions\n\nAPIs &amp; Frameworks — FastAPI | Flask | Streamli | Gradio\n\nData Analysis — Pandas | NumPy | Matplotlib | Plotly | Power BI\n\nOther Tools — Prometheus | Grafana | Git/GitHub | Linux | Pytest | LiveKit | Pydantic | LangSmith\n'},
#     {'title': 'VOLUNTEERING',
#      'node_id': '0012',
#      'page_index': 2,
#      'summary': '### VOLUNTEERING\n\nMember, AI Team - CIC Radix Team, Atlantis Underwater Robotics, ROV Competition\n\n- Built AI algorithms for underwater coral reef detection and plastic waste removal.\n',
#      'text': '### VOLUNTEERING\n\nMember, AI Team - CIC Radix Team, Atlantis Underwater Robotics, ROV Competition\n\n- Built AI algorithms for underwater coral reef detection and plastic waste removal.\n'}]}]}

# %%
def get_tree_toc(tree: list) -> list:
    try:
        toc_structure = []

        for node in tree:
            new_node = {
                "node_id": node.get("node_id"),
                "title": node.get("title"),
                "node_summary": node.get("node_summary") 
                                or node.get("summary") 
                                or node.get("prefix_summary", ""),
                "child_nodes": []
            }

            children = node.get("nodes", [])
            if children:
                new_node["child_nodes"] = get_tree_toc(children)

            toc_structure.append(new_node)

        return toc_structure

    except Exception:
        logger.exception("Error while trying to get_tree_toc")
        return []

# %%
get_tree_toc(tree)
# Out:
# [{'node_id': '0000',
#   'title': 'Data Science Portfolio',
#   'node_summary': '# Data Science Portfolio\n',
#   'child_nodes': []},
#  {'node_id': '0001',
#   'title': 'Skill Based Projects',
#   'node_summary': '# Skill Based Projects\n',
#   'child_nodes': [{'node_id': '0002',
#     'title': 'Data Analysis and Visualization:',
#     'node_summary': 'The text describes four data analysis and visualization projects: an EDA on Airbnb listings to understand demand trends; an analysis of electronics store sales data; a startup growth analysis with a focus on location, marketing, and revenue, including dashboard creation; and a project to track water funds for Maji Ndogo, emphasizing transparency and accountability by comparing budgets, project completion, team performance, and costs.',
#     'child_nodes': []},
#    {'node_id': '0003',
#     'title': 'Machine Learning:',
#     'node_summary': "## Machine Learning:\n\n- FastML With EDA python package (My own package) (https://github.com/Veto2922/Fast-Machine-Learning-With-EDA-python-package/tree/main/FastML_With_EDA): FastML_With_EDA is a versatile Python package designed to simplify the machine learning pipeline, from exploratory data analysis (EDA) and preprocessing to automated machine learning (AutoML) model training and evaluation. Whether you're a beginner or an experienced data scientist, FastML provides the tools you need to streamline your workflow and make data-driven decisions.\n- I also created a WEB APP (https://github.com/Veto2922/streamlit_app_for_FastML_With_EDA_python_package/tree/main) as GUI for this package\n",
#     'child_nodes': []},
#    {'node_id': '0004',
#     'title': 'Recommendation System',
#     'node_summary': '## Recommendation System\n\n- Rank and Knowledge base (https://github.com/Veto2922/Recommendation-system-course/tree/main/Task%201%20Rank-Based%2BKnowledge-Based%20Recommendations)\n- Content based (https://github.com/Veto2922/Movie-Recommender-System-content-based-)\n- Hybrid-based Book Recommendation System (https://github.com/Veto2922/hybrid-based-book-recommender-systems)\n',
#     'child_nodes': []},
#    {'node_id': '0005',
#     'title': 'Time series analysis and forecast',
#     'node_summary': '## Time series analysis and forecast\n\n- Monthly Retail Sales Forecasting (https://github.com/Veto2922/Advance-Monthly-Retail-Sales-Forecasting): This project involves forecasting the monthly sales for clothing and clothing accessory stores using LSTM (Long Short-Term Memory) neural networks. The dataset consists of monthly sales data (in millions of dollars, not seasonally adjusted) retrieved from the FRED, Federal Reserve Bank of St. Louis.\n- Time series forecasting using LSTM (https://github.com/Veto2922/Time-series-forecasting-using-LSTM/tree/main)\n',
#     'child_nodes': []},
#    {'node_id': '0006',
#     'title': 'Deep Learning:',
#     'node_summary': 'The text covers an introduction to Deep Learning and Artificial Neural Networks (ANN). It then details three projects utilizing TensorFlow and Keras: a regression project for housing price prediction involving data analysis and model building; a classification project for breast cancer diagnosis prediction that includes feature selection, data preprocessing, and overfitting mitigation techniques; and a deep learning project for predicting loan default on LendingClub data, focusing on historical loan features and loan status.',
#     'child_nodes': []},
#    {'node_id': '0007',
#     'title': 'Natural Language Processing (NLP):',
#     'node_summary': 'The text covers various Natural Language Processing (NLP) techniques and projects. These include text classification using TFIDF and GloVe with LSTM for disaster-related content, text generation with GRU, and sequence-to-sequence translation models implemented with LSTM and LSTM with Attention. It also details a from-scratch implementation of Transformers and a high-performing BERT-based text classification model using Huggingface, which achieved a top leaderboard score through fine-tuning and rigorous evaluation.',
#     'child_nodes': []}]}]

# %%
def get_docs_toc(pi_client: PageIndexClient , docs_index : list ):

    try:
        docs_tocs = []

        for i in docs_index:
            doc_id  = docs_list["documents"][i]['id']
            tree_result =  pi_client.get_tree( doc_id, node_summary=True)

            tree = tree_result.get("result" , [])

            

            docs_toc = {
                "doc_index": i,
                "doc_title": docs_list["documents"][i]["name"],
                "doc_toc" : get_tree_toc(tree)
            }

            docs_tocs.append(docs_toc)

        return docs_tocs

    except Exception as e:
        logger.exception('Error while trying to get_docs_toc')
        # return []

# %%
docs_list
# Out:
# {'documents': [{'id': 'pi-cmnnmjex1016w01qv2ej4ay36',
#    'name': 'projects_portfolio_in_github.pdf',
#    'description': 'This document outlines a data science portfolio showcasing projects in data analysis, visualization, machine learning, recommendation systems, time series forecasting, deep learning, and natural language processing.',
#    'status': 'completed',
#    'createdAt': '2026-04-06T20:09:43.265000',
#    'pageNum': 5,
#    'folderId': None},
#   {'id': 'pi-cmnnmjdi9016t01qvslbcf577',
#    'name': 'my_Linkedin.pdf',
#    'description': 'This document outlines the experience of Abdelrahman Mohamed, an AI Engineer specializing in LLM agents, RAG pipelines, and real-time AI assistants, with roles at Electro Pi, Sand Technologies, and ALX Arabia.',
#    'status': 'completed',
#    'createdAt': '2026-04-06T20:09:41.437000',
#    'pageNum': 4,
#    'folderId': None},
#   {'id': 'pi-cmnnmjcdr016q01qvn3cwv3ub',
#    'name': 'Abdelrahman_Mohamed_CV_14.9_1.pdf',
#    'description': 'This document is a resume for Abdelrahman Mohamed, an AI/ML Engineer with experience in GenAI systems, LLM fine-tuning, RAG pipelines, and real-time voice assistants, with a focus on Arabic AI applications.',
#    'status': 'completed',
#    'createdAt': '2026-04-06T20:09:39.983000',
#    'pageNum': 2,
#    'folderId': None}],
#  'total': 3,
#  'limit': 50,
#  'offset': 0}

# %%
get_docs_toc(pi_client= pi_client , docs_index = [1])
# Out:
# [{'doc_index': 1,
#   'doc_title': 'my_Linkedin.pdf',
#   'doc_toc': [{'node_id': '0000',
#     'title': 'Abdelrahman Mohamed',
#     'node_summary': '# Abdelrahman Mohamed\nAI Engineer @ Electro Pi | Specializing in ML, NLP, and LLMs | Build AI Agents &amp; Automations | Helping Startups Automate with LLMs\nCairo, Egypt\n',
#     'child_nodes': [{'node_id': '0001',
#       'title': 'Summary',
#       'node_summary': "## Summary\nI'm an AI Engineer passionate about building practical GenAI solutions. I work on real-world applications involving LLM agents, RAG pipelines, and real-time AI assistants.\n",
#       'child_nodes': []},
#      {'node_id': '0002',
#       'title': 'Experience',
#       'node_summary': 'This text details the experience of an AI Engineer at Electro Pi, focusing on the development and enhancement of AI systems. Key contributions include building a decision-making system with LLMs and advanced prompt engineering for financial reasoning, integrating RAG for dynamic financial chart generation, refactoring automation pipelines for improved maintainability, developing an AI sales agent with real-time recommendations and monitoring, contributing to voice agent systems for conversational AI, and working on computer vision projects for manufacturing defect detection.',
#       'child_nodes': [{'node_id': '0003',
#         'title': 'AI Engineer',
#         'node_summary': '### AI Engineer\n\nAugust 2024 - September 2024 (2 months)\n\nCairo, Egypt\n\n- Contributed to real-world AI projects, including harmful prompt detection and RAG-powered AI assistance using LangChain.\n- Worked on an AI-driven platform designed to help companies manage finances more efficiently, leveraging LLMs and machine learning models.\n- Playedakeyrole in integrating LLMs with financial models to process JSON data from Excel files, enabling automated extraction and calculation of financial insights based on user queries.\n',
#         'child_nodes': []},
#        {'node_id': '0004',
#         'title': 'Sand Technologies',
#         'node_summary': '### Sand Technologies\n\nData Scientist &amp; AI Engineer\n\nSeptember 2024 - Present (1 year 7 months)\n\nAssist startups in harnessing data and integrating AI and LLMs into their projects.\n',
#         'child_nodes': []},
#        {'node_id': '0005',
#         'title': 'ALX Arabia',
#         'node_summary': '### ALX Arabia\n\nScholarship\n\nMay 2023 - September 2024 (1 year 5 months)\n\nCairo, Egypt\n\nThis scholarship consists of 3 months of soft skills and approximately 11 months of studying data science from the Explore AI Academy curriculum.\n',
#         'child_nodes': []},
#        {'node_id': '0006',
#         'title': 'AI Rahma Medical Center',
#         'node_summary': '### AI Rahma Medical Center\n',
#         'child_nodes': [{'node_id': '0007',
#           'title': 'Data Analyst',
#           'node_summary': "The text details a Data Analyst role at Al-Rahma Medical Center where the individual was responsible for data transformation, cleaning, and dashboard development to support strategic decision-making for the medical center and its pharmacies. It also lists two Machine Learning Intern positions at SYNC INTERN'S and ApplAi, and educational background in Electrical, Electronics and Communications Engineering from CIC and a Data Science scholarship from ExploreAI Academy.",
#           'child_nodes': []}]}]}]}]}]

# %% [markdown]
# # search by doc_id and node id

# %%
# input = [{
#     "doc_index": 0,
#     "doc_nodes": [000]
# }]

# %%
doc_id  = docs_list["documents"][0]['id']
tree_result =  pi_client.get_tree( doc_id, node_summary=True)

# %%
tree_result.get("result")
# Out:
# [{'title': 'Data Science Portfolio',
#   'node_id': '0000',
#   'page_index': 1,
#   'summary': '# Data Science Portfolio\n',
#   'text': '# Data Science Portfolio\n'},
#  {'title': 'Skill Based Projects',
#   'node_id': '0001',
#   'page_index': 2,
#   'prefix_summary': '# Skill Based Projects\n',
#   'text': '# Skill Based Projects\n',
#   'nodes': [{'title': 'Data Analysis and Visualization:',
#     'node_id': '0002',
#     'page_index': 2,
#     'summary': 'The text describes four data analysis and visualization projects: an EDA on Airbnb listings to understand demand trends; an analysis of electronics store sales data; a startup growth analysis with a focus on location, marketing, and revenue, including dashboard creation; and a project to track water funds for Maji Ndogo, emphasizing transparency and accountability by comparing budgets, project completion, team performance, and costs.',
#     'text': "## Data Analysis and Visualization:\n\n- Airbnb-Listing-EDA (https://github.com/Veto2922/Airbnb-Listing-EDA): This project involves performing an exploratory data analysis (EDA) on Airbnb listing data for a particular city. The analysis focuses on factors such as price, availability, location, and property type to identify trends and patterns in the demand for Airbnb listings in the city. The project includes data cleaning, visualization, and statistical analysis.\n- Electronics store sales EDA (https://github.com/Veto2922/My-data-analysis-projects/tree/main/project1_Finance%20Problem): In this data analysis project, I took on the challenge of exploring 12 months' worth of sales data for an electronics store. The dataset included a vast array of purchase information, including product types, costs, purchase addresses, and more.\n- Startup expansion (https://github.com/Veto2922/My-data-analysis-projects/tree/main/project3_startup-expansion): In this project, I worked with a comprehensive dataset that provided valuable insights into the dynamics of startup growth, covering key aspects such as location, marketing spending, and revenue. and I made a Dashboard and Report To ensure that the project's insights were easily digestible\n- tracking Maji Ndogo's water funds (Power B0 (https://github.com/Veto2922/EXPLORE-AI-Integrated-project-Transparency-in-tracking-Maji-Ndogo-s-water-funds): Our mission is to communicate with transparency: Where did the money go? We will track the total budget against project completion, monitor teams' performance, and compare budgeted versus actual costs to flag potential corruption, promoting transparency and accountability in addressing Maji Ndogo's water crisis.\n"},
#    {'title': 'Machine Learning:',
#     'node_id': '0003',
#     'page_index': 3,
#     'summary': "## Machine Learning:\n\n- FastML With EDA python package (My own package) (https://github.com/Veto2922/Fast-Machine-Learning-With-EDA-python-package/tree/main/FastML_With_EDA): FastML_With_EDA is a versatile Python package designed to simplify the machine learning pipeline, from exploratory data analysis (EDA) and preprocessing to automated machine learning (AutoML) model training and evaluation. Whether you're a beginner or an experienced data scientist, FastML provides the tools you need to streamline your workflow and make data-driven decisions.\n- I also created a WEB APP (https://github.com/Veto2922/streamlit_app_for_FastML_With_EDA_python_package/tree/main) as GUI for this package\n",
#     'text': "## Machine Learning:\n\n- FastML With EDA python package (My own package) (https://github.com/Veto2922/Fast-Machine-Learning-With-EDA-python-package/tree/main/FastML_With_EDA): FastML_With_EDA is a versatile Python package designed to simplify the machine learning pipeline, from exploratory data analysis (EDA) and preprocessing to automated machine learning (AutoML) model training and evaluation. Whether you're a beginner or an experienced data scientist, FastML provides the tools you need to streamline your workflow and make data-driven decisions.\n- I also created a WEB APP (https://github.com/Veto2922/streamlit_app_for_FastML_With_EDA_python_package/tree/main) as GUI for this package\n"},
#    {'title': 'Recommendation System',
#     'node_id': '0004',
#     'page_index': 3,
#     'summary': '## Recommendation System\n\n- Rank and Knowledge base (https://github.com/Veto2922/Recommendation-system-course/tree/main/Task%201%20Rank-Based%2BKnowledge-Based%20Recommendations)\n- Content based (https://github.com/Veto2922/Movie-Recommender-System-content-based-)\n- Hybrid-based Book Recommendation System (https://github.com/Veto2922/hybrid-based-book-recommender-systems)\n',
#     'text': '## Recommendation System\n\n- Rank and Knowledge base (https://github.com/Veto2922/Recommendation-system-course/tree/main/Task%201%20Rank-Based%2BKnowledge-Based%20Recommendations)\n- Content based (https://github.com/Veto2922/Movie-Recommender-System-content-based-)\n- Hybrid-based Book Recommendation System (https://github.com/Veto2922/hybrid-based-book-recommender-systems)\n'},
#    {'title': 'Time series analysis and forecast',
#     'node_id': '0005',
#     'page_index': 3,
#     'summary': '## Time series analysis and forecast\n\n- Monthly Retail Sales Forecasting (https://github.com/Veto2922/Advance-Monthly-Retail-Sales-Forecasting): This project involves forecasting the monthly sales for clothing and clothing accessory stores using LSTM (Long Short-Term Memory) neural networks. The dataset consists of monthly sales data (in millions of dollars, not seasonally adjusted) retrieved from the FRED, Federal Reserve Bank of St. Louis.\n- Time series forecasting using LSTM (https://github.com/Veto2922/Time-series-forecasting-using-LSTM/tree/main)\n',
#     'text': '## Time series analysis and forecast\n\n- Monthly Retail Sales Forecasting (https://github.com/Veto2922/Advance-Monthly-Retail-Sales-Forecasting): This project involves forecasting the monthly sales for clothing and clothing accessory stores using LSTM (Long Short-Term Memory) neural networks. The dataset consists of monthly sales data (in millions of dollars, not seasonally adjusted) retrieved from the FRED, Federal Reserve Bank of St. Louis.\n- Time series forecasting using LSTM (https://github.com/Veto2922/Time-series-forecasting-using-LSTM/tree/main)\n'},
#    {'title': 'Deep Learning:',
#     'node_id': '0006',
#     'page_index': 3,
#     'summary': 'The text covers an introduction to Deep Learning and Artificial Neural Networks (ANN). It then details three projects utilizing TensorFlow and Keras: a regression project for housing price prediction involving data analysis and model building; a classification project for breast cancer diagnosis prediction that includes feature selection, data preprocessing, and overfitting mitigation techniques; and a deep learning project for predicting loan default on LendingClub data, focusing on historical loan features and loan status.',
#     'text': '## Deep Learning:\n\nANN\n\n- Tanserflow and keras regression (https://colab.research.google.com/drive/1iuFkq_R-8jfBVDSdLUDOOnvSf16mG5D1?usp=sharing): This project analyzes housing data using Pandas, NumPy, and TensorFlow &amp; keras. It explores data distribution, geographical properties, and performs feature engineering. A neural network model is built, trained, and evaluated for predicting house prices, achieving insights and predictions.\n- Tanserflow and keras classification (https://colab.research.google.com/drive/169CJUosBsreu5rS-qFrAi39mTyu7nvP2?usp=sharing): The project conducts t-tests on each feature to assess its significance in predicting a binary target variable (breast cancer diagnosis). It then selects features with p-values below a significance level (0.05). The data is split into training and testing sets, scaled, and used to train a neural network model. And addresses overfitting by implementing early stopping and dropout techniques in the neural network model\n- LendingClub Loan Default Prediction (https://drive.google.com/file/d/1f6csdAqDWvsNOUik-RGMIGmyq7nelqJ5/view?usp=sharing): This project aims to build a Deep learning model to predict whether a borrower will repay their loan based on historical loan data from LendingClub. LendingClub is a peer-to-peer lending platform that facilitates loan origination by connecting borrowers with investors. The dataset includes various features such as loan amount, interest rate, borrower employment details, and credit history. The main target variable for prediction is loan_status, which indicates if a loan was "Fully Paid" or "Charged Off" (defaulted).\n'},
#    {'title': 'Natural Language Processing (NLP):',
#     'node_id': '0007',
#     'page_index': 4,
#     'summary': 'The text covers various Natural Language Processing (NLP) techniques and projects. These include text classification using TFIDF and GloVe with LSTM for disaster-related content, text generation with GRU, and sequence-to-sequence translation models implemented with LSTM and LSTM with Attention. It also details a from-scratch implementation of Transformers and a high-performing BERT-based text classification model using Huggingface, which achieved a top leaderboard score through fine-tuning and rigorous evaluation.',
#     'text': "## Natural Language Processing (NLP):\n\n- Text classification using TFIDF (https://colab.research.google.com/drive/19Jl8nvJL5kZ84d2qRi3VwwDMY2WL4ZIS?usp=sharing): The goal of this project is to develop a machine learning model that can accurately classify tweets as either related to real disasters or not.\n- Text Classification with GloVe and LSTM (https://colab.research.google.com/drive/1W6kHzMh7iX5y6JZV731teVVRKyyMpg_u?usp=sharing): This project employs LSTM neural networks for text classification on disaster-related messages. It preprocesses and tokenizes text data, utilizes pre-trained word embeddings, and trains the model with Keras. Finally, it evaluates the model's performance, generates predictions, and creates a submission file for Kaggle competition.\n\n- Text Generation with GRU (https://colab.research.google.com/drive/1mixPpl1DGjgSGhu2xYTx4Jyd4p1NHrjs?usp=sharing): This code employs TensorFlow and Keras to build a text generation model. It preprocesses Shakespearean text data, creating sequences for training. The model architecture includes an Embedding layer and a GRU layer. After training, the model can generate text based on given starting seeds. This approach facilitates the generation of coherent text sequences.\n\n- Seq2seq Translation model with LSTM implementation (https://colab.research.google.com/drive/1Ffq3WFRfRFoo-CNLidxCDbtO4jFEwcp0?usp=sharing)\n\n- Seq2seq Translation model with LSTM + Attention implementation (https://colab.research.google.com/drive/1B?tMIEDccE4WGBhwci-ylqXADdu_oXav?usp=sharing)\n\n- Transformers Implementation From scratch (https://colab.research.google.com/drive/1YqtJlJrpaPWtKueitdSCLb1v7tLYhqPZ?usp=sharing)\n\n- Text Classification With BERT huggingface (https://www.kaggle.com/code/abdalrahminmohammed/bert-fine-tuning-with-huggingface): -Leaderboard Score: 0.99872 (first in the Leaderboard)\n\n- Loaded the pre-trained distillery-base-uncased model for sequence classification.\n- Set up training arguments and fine-tuned the model using a Trainer object.\n- Trained the model on the tokenized datasets and evaluated it using accuracy and F1 score metrics.\n- Predicted on the validation set in batches, calculated evaluation metrics (confusion matrix, classification report, F1 score).\n- Achieved high accuracy and F1 score on the validation set, indicating a well-performing model.\n"}]}]

# %%
# O(1) instead of O(N)
def build_index(nodes):
    index = {}

    def dfs(node_list):
        for node in node_list:
            index[node["node_id"]] = node
            if "nodes" in node:
                dfs(node["nodes"])

    dfs(nodes)
    
    return index

# %%
index = build_index(tree)

target_ids = ["0000", "0001"]

results = [
    {
        "node_id": nid,
        "title": index[nid].get("title"),
        "page_num": index[nid].get("page_index"),
        "node_text": index[nid].get("text"),
        "child_nodes": index[nid].get("nodes", [])
    }
    for nid in target_ids
    if nid in index
]

results
# Out:
# [{'node_id': '0000',
#   'title': 'Data Science Portfolio',
#   'page_num': 1,
#   'node_text': '# Data Science Portfolio\n',
#   'child_nodes': []},
#  {'node_id': '0001',
#   'title': 'Skill Based Projects',
#   'page_num': 2,
#   'node_text': '# Skill Based Projects\n',
#   'child_nodes': [{'title': 'Data Analysis and Visualization:',
#     'node_id': '0002',
#     'page_index': 2,
#     'summary': 'The text describes four data analysis and visualization projects: an EDA on Airbnb listings to understand demand trends; an analysis of electronics store sales data; a startup growth analysis with a focus on location, marketing, and revenue, including dashboard creation; and a project to track water funds for Maji Ndogo, emphasizing transparency and accountability by comparing budgets, project completion, team performance, and costs.',
#     'text': "## Data Analysis and Visualization:\n\n- Airbnb-Listing-EDA (https://github.com/Veto2922/Airbnb-Listing-EDA): This project involves performing an exploratory data analysis (EDA) on Airbnb listing data for a particular city. The analysis focuses on factors such as price, availability, location, and property type to identify trends and patterns in the demand for Airbnb listings in the city. The project includes data cleaning, visualization, and statistical analysis.\n- Electronics store sales EDA (https://github.com/Veto2922/My-data-analysis-projects/tree/main/project1_Finance%20Problem): In this data analysis project, I took on the challenge of exploring 12 months' worth of sales data for an electronics store. The dataset included a vast array of purchase information, including product types, costs, purchase addresses, and more.\n- Startup expansion (https://github.com/Veto2922/My-data-analysis-projects/tree/main/project3_startup-expansion): In this project, I worked with a comprehensive dataset that provided valuable insights into the dynamics of startup growth, covering key aspects such as location, marketing spending, and revenue. and I made a Dashboard and Report To ensure that the project's insights were easily digestible\n- tracking Maji Ndogo's water funds (Power B0 (https://github.com/Veto2922/EXPLORE-AI-Integrated-project-Transparency-in-tracking-Maji-Ndogo-s-water-funds): Our mission is to communicate with transparency: Where did the money go? We will track the total budget against project completion, monitor teams' performance, and compare budgeted versus actual costs to flag potential corruption, promoting transparency and accountability in addressing Maji Ndogo's water crisis.\n"},
#    {'title': 'Machine Learning:',
#     'node_id': '0003',
#     'page_index': 3,
#     'summary': "## Machine Learning:\n\n- FastML With EDA python package (My own package) (https://github.com/Veto2922/Fast-Machine-Learning-With-EDA-python-package/tree/main/FastML_With_EDA): FastML_With_EDA is a versatile Python package designed to simplify the machine learning pipeline, from exploratory data analysis (EDA) and preprocessing to automated machine learning (AutoML) model training and evaluation. Whether you're a beginner or an experienced data scientist, FastML provides the tools you need to streamline your workflow and make data-driven decisions.\n- I also created a WEB APP (https://github.com/Veto2922/streamlit_app_for_FastML_With_EDA_python_package/tree/main) as GUI for this package\n",
#     'text': "## Machine Learning:\n\n- FastML With EDA python package (My own package) (https://github.com/Veto2922/Fast-Machine-Learning-With-EDA-python-package/tree/main/FastML_With_EDA): FastML_With_EDA is a versatile Python package designed to simplify the machine learning pipeline, from exploratory data analysis (EDA) and preprocessing to automated machine learning (AutoML) model training and evaluation. Whether you're a beginner or an experienced data scientist, FastML provides the tools you need to streamline your workflow and make data-driven decisions.\n- I also created a WEB APP (https://github.com/Veto2922/streamlit_app_for_FastML_With_EDA_python_package/tree/main) as GUI for this package\n"},
#    {'title': 'Recommendation System',
#     'node_id': '0004',
#     'page_index': 3,
#     'summary': '## Recommendation System\n\n- Rank and Knowledge base (https://github.com/Veto2922/Recommendation-system-course/tree/main/Task%201%20Rank-Based%2BKnowledge-Based%20Recommendations)\n- Content based (https://github.com/Veto2922/Movie-Recommender-System-content-based-)\n- Hybrid-based Book Recommendation System (https://github.com/Veto2922/hybrid-based-book-recommender-systems)\n',
#     'text': '## Recommendation System\n\n- Rank and Knowledge base (https://github.com/Veto2922/Recommendation-system-course/tree/main/Task%201%20Rank-Based%2BKnowledge-Based%20Recommendations)\n- Content based (https://github.com/Veto2922/Movie-Recommender-System-content-based-)\n- Hybrid-based Book Recommendation System (https://github.com/Veto2922/hybrid-based-book-recommender-systems)\n'},
#    {'title': 'Time series analysis and forecast',
#     'node_id': '0005',
#     'page_index': 3,
#     'summary': '## Time series analysis and forecast\n\n- Monthly Retail Sales Forecasting (https://github.com/Veto2922/Advance-Monthly-Retail-Sales-Forecasting): This project involves forecasting the monthly sales for clothing and clothing accessory stores using LSTM (Long Short-Term Memory) neural networks. The dataset consists of monthly sales data (in millions of dollars, not seasonally adjusted) retrieved from the FRED, Federal Reserve Bank of St. Louis.\n- Time series forecasting using LSTM (https://github.com/Veto2922/Time-series-forecasting-using-LSTM/tree/main)\n',
#     'text': '## Time series analysis and forecast\n\n- Monthly Retail Sales Forecasting (https://github.com/Veto2922/Advance-Monthly-Retail-Sales-Forecasting): This project involves forecasting the monthly sales for clothing and clothing accessory stores using LSTM (Long Short-Term Memory) neural networks. The dataset consists of monthly sales data (in millions of dollars, not seasonally adjusted) retrieved from the FRED, Federal Reserve Bank of St. Louis.\n- Time series forecasting using LSTM (https://github.com/Veto2922/Time-series-forecasting-using-LSTM/tree/main)\n'},
#    {'title': 'Deep Learning:',
#     'node_id': '0006',
#     'page_index': 3,
#     'summary': 'The text covers an introduction to Deep Learning and Artificial Neural Networks (ANN). It then details three projects utilizing TensorFlow and Keras: a regression project for housing price prediction involving data analysis and model building; a classification project for breast cancer diagnosis prediction that includes feature selection, data preprocessing, and overfitting mitigation techniques; and a deep learning project for predicting loan default on LendingClub data, focusing on historical loan features and loan status.',
#     'text': '## Deep Learning:\n\nANN\n\n- Tanserflow and keras regression (https://colab.research.google.com/drive/1iuFkq_R-8jfBVDSdLUDOOnvSf16mG5D1?usp=sharing): This project analyzes housing data using Pandas, NumPy, and TensorFlow &amp; keras. It explores data distribution, geographical properties, and performs feature engineering. A neural network model is built, trained, and evaluated for predicting house prices, achieving insights and predictions.\n- Tanserflow and keras classification (https://colab.research.google.com/drive/169CJUosBsreu5rS-qFrAi39mTyu7nvP2?usp=sharing): The project conducts t-tests on each feature to assess its significance in predicting a binary target variable (breast cancer diagnosis). It then selects features with p-values below a significance level (0.05). The data is split into training and testing sets, scaled, and used to train a neural network model. And addresses overfitting by implementing early stopping and dropout techniques in the neural network model\n- LendingClub Loan Default Prediction (https://drive.google.com/file/d/1f6csdAqDWvsNOUik-RGMIGmyq7nelqJ5/view?usp=sharing): This project aims to build a Deep learning model to predict whether a borrower will repay their loan based on historical loan data from LendingClub. LendingClub is a peer-to-peer lending platform that facilitates loan origination by connecting borrowers with investors. The dataset includes various features such as loan amount, interest rate, borrower employment details, and credit history. The main target variable for prediction is loan_status, which indicates if a loan was "Fully Paid" or "Charged Off" (defaulted).\n'},
#    {'title': 'Natural Language Processing (NLP):',
#     'node_id': '0007',
#     'page_index': 4,
#     'summary': 'The text covers various Natural Language Processing (NLP) techniques and projects. These include text classification using TFIDF and GloVe with LSTM for disaster-related content, text generation with GRU, and sequence-to-sequence translation models implemented with LSTM and LSTM with Attention. It also details a from-scratch implementation of Transformers and a high-performing BERT-based text classification model using Huggingface, which achieved a top leaderboard score through fine-tuning and rigorous evaluation.',
#     'text': "## Natural Language Processing (NLP):\n\n- Text classification using TFIDF (https://colab.research.google.com/drive/19Jl8nvJL5kZ84d2qRi3VwwDMY2WL4ZIS?usp=sharing): The goal of this project is to develop a machine learning model that can accurately classify tweets as either related to real disasters or not.\n- Text Classification with GloVe and LSTM (https://colab.research.google.com/drive/1W6kHzMh7iX5y6JZV731teVVRKyyMpg_u?usp=sharing): This project employs LSTM neural networks for text classification on disaster-related messages. It preprocesses and tokenizes text data, utilizes pre-trained word embeddings, and trains the model with Keras. Finally, it evaluates the model's performance, generates predictions, and creates a submission file for Kaggle competition.\n\n- Text Generation with GRU (https://colab.research.google.com/drive/1mixPpl1DGjgSGhu2xYTx4Jyd4p1NHrjs?usp=sharing): This code employs TensorFlow and Keras to build a text generation model. It preprocesses Shakespearean text data, creating sequences for training. The model architecture includes an Embedding layer and a GRU layer. After training, the model can generate text based on given starting seeds. This approach facilitates the generation of coherent text sequences.\n\n- Seq2seq Translation model with LSTM implementation (https://colab.research.google.com/drive/1Ffq3WFRfRFoo-CNLidxCDbtO4jFEwcp0?usp=sharing)\n\n- Seq2seq Translation model with LSTM + Attention implementation (https://colab.research.google.com/drive/1B?tMIEDccE4WGBhwci-ylqXADdu_oXav?usp=sharing)\n\n- Transformers Implementation From scratch (https://colab.research.google.com/drive/1YqtJlJrpaPWtKueitdSCLb1v7tLYhqPZ?usp=sharing)\n\n- Text Classification With BERT huggingface (https://www.kaggle.com/code/abdalrahminmohammed/bert-fine-tuning-with-huggingface): -Leaderboard Score: 0.99872 (first in the Leaderboard)\n\n- Loaded the pre-trained distillery-base-uncased model for sequence classification.\n- Set up training arguments and fine-tuned the model using a Trainer object.\n- Trained the model on the tokenized datasets and evaluated it using accuracy and F1 score metrics.\n- Predicted on the validation set in batches, calculated evaluation metrics (confusion matrix, classification report, F1 score).\n- Achieved high accuracy and F1 score on the validation set, indicating a well-performing model.\n"}]}]

# %%
index
# Out:
# {'0000': {'title': 'Data Science Portfolio',
#   'node_id': '0000',
#   'page_index': 1,
#   'summary': '# Data Science Portfolio\n',
#   'text': '# Data Science Portfolio\n'},
#  '0001': {'title': 'Skill Based Projects',
#   'node_id': '0001',
#   'page_index': 2,
#   'prefix_summary': '# Skill Based Projects\n',
#   'text': '# Skill Based Projects\n',
#   'nodes': [{'title': 'Data Analysis and Visualization:',
#     'node_id': '0002',
#     'page_index': 2,
#     'summary': 'The text describes four data analysis and visualization projects: an EDA on Airbnb listings to understand demand trends; an analysis of electronics store sales data; a startup growth analysis with a focus on location, marketing, and revenue, including dashboard creation; and a project to track water funds for Maji Ndogo, emphasizing transparency and accountability by comparing budgets, project completion, team performance, and costs.',
#     'text': "## Data Analysis and Visualization:\n\n- Airbnb-Listing-EDA (https://github.com/Veto2922/Airbnb-Listing-EDA): This project involves performing an exploratory data analysis (EDA) on Airbnb listing data for a particular city. The analysis focuses on factors such as price, availability, location, and property type to identify trends and patterns in the demand for Airbnb listings in the city. The project includes data cleaning, visualization, and statistical analysis.\n- Electronics store sales EDA (https://github.com/Veto2922/My-data-analysis-projects/tree/main/project1_Finance%20Problem): In this data analysis project, I took on the challenge of exploring 12 months' worth of sales data for an electronics store. The dataset included a vast array of purchase information, including product types, costs, purchase addresses, and more.\n- Startup expansion (https://github.com/Veto2922/My-data-analysis-projects/tree/main/project3_startup-expansion): In this project, I worked with a comprehensive dataset that provided valuable insights into the dynamics of startup growth, covering key aspects such as location, marketing spending, and revenue. and I made a Dashboard and Report To ensure that the project's insights were easily digestible\n- tracking Maji Ndogo's water funds (Power B0 (https://github.com/Veto2922/EXPLORE-AI-Integrated-project-Transparency-in-tracking-Maji-Ndogo-s-water-funds): Our mission is to communicate with transparency: Where did the money go? We will track the total budget against project completion, monitor teams' performance, and compare budgeted versus actual costs to flag potential corruption, promoting transparency and accountability in addressing Maji Ndogo's water crisis.\n"},
#    {'title': 'Machine Learning:',
#     'node_id': '0003',
#     'page_index': 3,
#     'summary': "## Machine Learning:\n\n- FastML With EDA python package (My own package) (https://github.com/Veto2922/Fast-Machine-Learning-With-EDA-python-package/tree/main/FastML_With_EDA): FastML_With_EDA is a versatile Python package designed to simplify the machine learning pipeline, from exploratory data analysis (EDA) and preprocessing to automated machine learning (AutoML) model training and evaluation. Whether you're a beginner or an experienced data scientist, FastML provides the tools you need to streamline your workflow and make data-driven decisions.\n- I also created a WEB APP (https://github.com/Veto2922/streamlit_app_for_FastML_With_EDA_python_package/tree/main) as GUI for this package\n",
#     'text': "## Machine Learning:\n\n- FastML With EDA python package (My own package) (https://github.com/Veto2922/Fast-Machine-Learning-With-EDA-python-package/tree/main/FastML_With_EDA): FastML_With_EDA is a versatile Python package designed to simplify the machine learning pipeline, from exploratory data analysis (EDA) and preprocessing to automated machine learning (AutoML) model training and evaluation. Whether you're a beginner or an experienced data scientist, FastML provides the tools you need to streamline your workflow and make data-driven decisions.\n- I also created a WEB APP (https://github.com/Veto2922/streamlit_app_for_FastML_With_EDA_python_package/tree/main) as GUI for this package\n"},
#    {'title': 'Recommendation System',
#     'node_id': '0004',
#     'page_index': 3,
#     'summary': '## Recommendation System\n\n- Rank and Knowledge base (https://github.com/Veto2922/Recommendation-system-course/tree/main/Task%201%20Rank-Based%2BKnowledge-Based%20Recommendations)\n- Content based (https://github.com/Veto2922/Movie-Recommender-System-content-based-)\n- Hybrid-based Book Recommendation System (https://github.com/Veto2922/hybrid-based-book-recommender-systems)\n',
#     'text': '## Recommendation System\n\n- Rank and Knowledge base (https://github.com/Veto2922/Recommendation-system-course/tree/main/Task%201%20Rank-Based%2BKnowledge-Based%20Recommendations)\n- Content based (https://github.com/Veto2922/Movie-Recommender-System-content-based-)\n- Hybrid-based Book Recommendation System (https://github.com/Veto2922/hybrid-based-book-recommender-systems)\n'},
#    {'title': 'Time series analysis and forecast',
#     'node_id': '0005',
#     'page_index': 3,
#     'summary': '## Time series analysis and forecast\n\n- Monthly Retail Sales Forecasting (https://github.com/Veto2922/Advance-Monthly-Retail-Sales-Forecasting): This project involves forecasting the monthly sales for clothing and clothing accessory stores using LSTM (Long Short-Term Memory) neural networks. The dataset consists of monthly sales data (in millions of dollars, not seasonally adjusted) retrieved from the FRED, Federal Reserve Bank of St. Louis.\n- Time series forecasting using LSTM (https://github.com/Veto2922/Time-series-forecasting-using-LSTM/tree/main)\n',
#     'text': '## Time series analysis and forecast\n\n- Monthly Retail Sales Forecasting (https://github.com/Veto2922/Advance-Monthly-Retail-Sales-Forecasting): This project involves forecasting the monthly sales for clothing and clothing accessory stores using LSTM (Long Short-Term Memory) neural networks. The dataset consists of monthly sales data (in millions of dollars, not seasonally adjusted) retrieved from the FRED, Federal Reserve Bank of St. Louis.\n- Time series forecasting using LSTM (https://github.com/Veto2922/Time-series-forecasting-using-LSTM/tree/main)\n'},
#    {'title': 'Deep Learning:',
#     'node_id': '0006',
#     'page_index': 3,
#     'summary': 'The text covers an introduction to Deep Learning and Artificial Neural Networks (ANN). It then details three projects utilizing TensorFlow and Keras: a regression project for housing price prediction involving data analysis and model building; a classification project for breast cancer diagnosis prediction that includes feature selection, data preprocessing, and overfitting mitigation techniques; and a deep learning project for predicting loan default on LendingClub data, focusing on historical loan features and loan status.',
#     'text': '## Deep Learning:\n\nANN\n\n- Tanserflow and keras regression (https://colab.research.google.com/drive/1iuFkq_R-8jfBVDSdLUDOOnvSf16mG5D1?usp=sharing): This project analyzes housing data using Pandas, NumPy, and TensorFlow &amp; keras. It explores data distribution, geographical properties, and performs feature engineering. A neural network model is built, trained, and evaluated for predicting house prices, achieving insights and predictions.\n- Tanserflow and keras classification (https://colab.research.google.com/drive/169CJUosBsreu5rS-qFrAi39mTyu7nvP2?usp=sharing): The project conducts t-tests on each feature to assess its significance in predicting a binary target variable (breast cancer diagnosis). It then selects features with p-values below a significance level (0.05). The data is split into training and testing sets, scaled, and used to train a neural network model. And addresses overfitting by implementing early stopping and dropout techniques in the neural network model\n- LendingClub Loan Default Prediction (https://drive.google.com/file/d/1f6csdAqDWvsNOUik-RGMIGmyq7nelqJ5/view?usp=sharing): This project aims to build a Deep learning model to predict whether a borrower will repay their loan based on historical loan data from LendingClub. LendingClub is a peer-to-peer lending platform that facilitates loan origination by connecting borrowers with investors. The dataset includes various features such as loan amount, interest rate, borrower employment details, and credit history. The main target variable for prediction is loan_status, which indicates if a loan was "Fully Paid" or "Charged Off" (defaulted).\n'},
#    {'title': 'Natural Language Processing (NLP):',
#     'node_id': '0007',
#     'page_index': 4,
#     'summary': 'The text covers various Natural Language Processing (NLP) techniques and projects. These include text classification using TFIDF and GloVe with LSTM for disaster-related content, text generation with GRU, and sequence-to-sequence translation models implemented with LSTM and LSTM with Attention. It also details a from-scratch implementation of Transformers and a high-performing BERT-based text classification model using Huggingface, which achieved a top leaderboard score through fine-tuning and rigorous evaluation.',
#     'text': "## Natural Language Processing (NLP):\n\n- Text classification using TFIDF (https://colab.research.google.com/drive/19Jl8nvJL5kZ84d2qRi3VwwDMY2WL4ZIS?usp=sharing): The goal of this project is to develop a machine learning model that can accurately classify tweets as either related to real disasters or not.\n- Text Classification with GloVe and LSTM (https://colab.research.google.com/drive/1W6kHzMh7iX5y6JZV731teVVRKyyMpg_u?usp=sharing): This project employs LSTM neural networks for text classification on disaster-related messages. It preprocesses and tokenizes text data, utilizes pre-trained word embeddings, and trains the model with Keras. Finally, it evaluates the model's performance, generates predictions, and creates a submission file for Kaggle competition.\n\n- Text Generation with GRU (https://colab.research.google.com/drive/1mixPpl1DGjgSGhu2xYTx4Jyd4p1NHrjs?usp=sharing): This code employs TensorFlow and Keras to build a text generation model. It preprocesses Shakespearean text data, creating sequences for training. The model architecture includes an Embedding layer and a GRU layer. After training, the model can generate text based on given starting seeds. This approach facilitates the generation of coherent text sequences.\n\n- Seq2seq Translation model with LSTM implementation (https://colab.research.google.com/drive/1Ffq3WFRfRFoo-CNLidxCDbtO4jFEwcp0?usp=sharing)\n\n- Seq2seq Translation model with LSTM + Attention implementation (https://colab.research.google.com/drive/1B?tMIEDccE4WGBhwci-ylqXADdu_oXav?usp=sharing)\n\n- Transformers Implementation From scratch (https://colab.research.google.com/drive/1YqtJlJrpaPWtKueitdSCLb1v7tLYhqPZ?usp=sharing)\n\n- Text Classification With BERT huggingface (https://www.kaggle.com/code/abdalrahminmohammed/bert-fine-tuning-with-huggingface): -Leaderboard Score: 0.99872 (first in the Leaderboard)\n\n- Loaded the pre-trained distillery-base-uncased model for sequence classification.\n- Set up training arguments and fine-tuned the model using a Trainer object.\n- Trained the model on the tokenized datasets and evaluated it using accuracy and F1 score metrics.\n- Predicted on the validation set in batches, calculated evaluation metrics (confusion matrix, classification report, F1 score).\n- Achieved high accuracy and F1 score on the validation set, indicating a well-performing model.\n"}]},
#  '0002': {'title': 'Data Analysis and Visualization:',
#   'node_id': '0002',
#   'page_index': 2,
#   'summary': 'The text describes four data analysis and visualization projects: an EDA on Airbnb listings to understand demand trends; an analysis of electronics store sales data; a startup growth analysis with a focus on location, marketing, and revenue, including dashboard creation; and a project to track water funds for Maji Ndogo, emphasizing transparency and accountability by comparing budgets, project completion, team performance, and costs.',
#   'text': "## Data Analysis and Visualization:\n\n- Airbnb-Listing-EDA (https://github.com/Veto2922/Airbnb-Listing-EDA): This project involves performing an exploratory data analysis (EDA) on Airbnb listing data for a particular city. The analysis focuses on factors such as price, availability, location, and property type to identify trends and patterns in the demand for Airbnb listings in the city. The project includes data cleaning, visualization, and statistical analysis.\n- Electronics store sales EDA (https://github.com/Veto2922/My-data-analysis-projects/tree/main/project1_Finance%20Problem): In this data analysis project, I took on the challenge of exploring 12 months' worth of sales data for an electronics store. The dataset included a vast array of purchase information, including product types, costs, purchase addresses, and more.\n- Startup expansion (https://github.com/Veto2922/My-data-analysis-projects/tree/main/project3_startup-expansion): In this project, I worked with a comprehensive dataset that provided valuable insights into the dynamics of startup growth, covering key aspects such as location, marketing spending, and revenue. and I made a Dashboard and Report To ensure that the project's insights were easily digestible\n- tracking Maji Ndogo's water funds (Power B0 (https://github.com/Veto2922/EXPLORE-AI-Integrated-project-Transparency-in-tracking-Maji-Ndogo-s-water-funds): Our mission is to communicate with transparency: Where did the money go? We will track the total budget against project completion, monitor teams' performance, and compare budgeted versus actual costs to flag potential corruption, promoting transparency and accountability in addressing Maji Ndogo's water crisis.\n"},
#  '0003': {'title': 'Machine Learning:',
#   'node_id': '0003',
#   'page_index': 3,
#   'summary': "## Machine Learning:\n\n- FastML With EDA python package (My own package) (https://github.com/Veto2922/Fast-Machine-Learning-With-EDA-python-package/tree/main/FastML_With_EDA): FastML_With_EDA is a versatile Python package designed to simplify the machine learning pipeline, from exploratory data analysis (EDA) and preprocessing to automated machine learning (AutoML) model training and evaluation. Whether you're a beginner or an experienced data scientist, FastML provides the tools you need to streamline your workflow and make data-driven decisions.\n- I also created a WEB APP (https://github.com/Veto2922/streamlit_app_for_FastML_With_EDA_python_package/tree/main) as GUI for this package\n",
#   'text': "## Machine Learning:\n\n- FastML With EDA python package (My own package) (https://github.com/Veto2922/Fast-Machine-Learning-With-EDA-python-package/tree/main/FastML_With_EDA): FastML_With_EDA is a versatile Python package designed to simplify the machine learning pipeline, from exploratory data analysis (EDA) and preprocessing to automated machine learning (AutoML) model training and evaluation. Whether you're a beginner or an experienced data scientist, FastML provides the tools you need to streamline your workflow and make data-driven decisions.\n- I also created a WEB APP (https://github.com/Veto2922/streamlit_app_for_FastML_With_EDA_python_package/tree/main) as GUI for this package\n"},
#  '0004': {'title': 'Recommendation System',
#   'node_id': '0004',
#   'page_index': 3,
#   'summary': '## Recommendation System\n\n- Rank and Knowledge base (https://github.com/Veto2922/Recommendation-system-course/tree/main/Task%201%20Rank-Based%2BKnowledge-Based%20Recommendations)\n- Content based (https://github.com/Veto2922/Movie-Recommender-System-content-based-)\n- Hybrid-based Book Recommendation System (https://github.com/Veto2922/hybrid-based-book-recommender-systems)\n',
#   'text': '## Recommendation System\n\n- Rank and Knowledge base (https://github.com/Veto2922/Recommendation-system-course/tree/main/Task%201%20Rank-Based%2BKnowledge-Based%20Recommendations)\n- Content based (https://github.com/Veto2922/Movie-Recommender-System-content-based-)\n- Hybrid-based Book Recommendation System (https://github.com/Veto2922/hybrid-based-book-recommender-systems)\n'},
#  '0005': {'title': 'Time series analysis and forecast',
#   'node_id': '0005',
#   'page_index': 3,
#   'summary': '## Time series analysis and forecast\n\n- Monthly Retail Sales Forecasting (https://github.com/Veto2922/Advance-Monthly-Retail-Sales-Forecasting): This project involves forecasting the monthly sales for clothing and clothing accessory stores using LSTM (Long Short-Term Memory) neural networks. The dataset consists of monthly sales data (in millions of dollars, not seasonally adjusted) retrieved from the FRED, Federal Reserve Bank of St. Louis.\n- Time series forecasting using LSTM (https://github.com/Veto2922/Time-series-forecasting-using-LSTM/tree/main)\n',
#   'text': '## Time series analysis and forecast\n\n- Monthly Retail Sales Forecasting (https://github.com/Veto2922/Advance-Monthly-Retail-Sales-Forecasting): This project involves forecasting the monthly sales for clothing and clothing accessory stores using LSTM (Long Short-Term Memory) neural networks. The dataset consists of monthly sales data (in millions of dollars, not seasonally adjusted) retrieved from the FRED, Federal Reserve Bank of St. Louis.\n- Time series forecasting using LSTM (https://github.com/Veto2922/Time-series-forecasting-using-LSTM/tree/main)\n'},
#  '0006': {'title': 'Deep Learning:',
#   'node_id': '0006',
#   'page_index': 3,
#   'summary': 'The text covers an introduction to Deep Learning and Artificial Neural Networks (ANN). It then details three projects utilizing TensorFlow and Keras: a regression project for housing price prediction involving data analysis and model building; a classification project for breast cancer diagnosis prediction that includes feature selection, data preprocessing, and overfitting mitigation techniques; and a deep learning project for predicting loan default on LendingClub data, focusing on historical loan features and loan status.',
#   'text': '## Deep Learning:\n\nANN\n\n- Tanserflow and keras regression (https://colab.research.google.com/drive/1iuFkq_R-8jfBVDSdLUDOOnvSf16mG5D1?usp=sharing): This project analyzes housing data using Pandas, NumPy, and TensorFlow &amp; keras. It explores data distribution, geographical properties, and performs feature engineering. A neural network model is built, trained, and evaluated for predicting house prices, achieving insights and predictions.\n- Tanserflow and keras classification (https://colab.research.google.com/drive/169CJUosBsreu5rS-qFrAi39mTyu7nvP2?usp=sharing): The project conducts t-tests on each feature to assess its significance in predicting a binary target variable (breast cancer diagnosis). It then selects features with p-values below a significance level (0.05). The data is split into training and testing sets, scaled, and used to train a neural network model. And addresses overfitting by implementing early stopping and dropout techniques in the neural network model\n- LendingClub Loan Default Prediction (https://drive.google.com/file/d/1f6csdAqDWvsNOUik-RGMIGmyq7nelqJ5/view?usp=sharing): This project aims to build a Deep learning model to predict whether a borrower will repay their loan based on historical loan data from LendingClub. LendingClub is a peer-to-peer lending platform that facilitates loan origination by connecting borrowers with investors. The dataset includes various features such as loan amount, interest rate, borrower employment details, and credit history. The main target variable for prediction is loan_status, which indicates if a loan was "Fully Paid" or "Charged Off" (defaulted).\n'},
#  '0007': {'title': 'Natural Language Processing (NLP):',
#   'node_id': '0007',
#   'page_index': 4,
#   'summary': 'The text covers various Natural Language Processing (NLP) techniques and projects. These include text classification using TFIDF and GloVe with LSTM for disaster-related content, text generation with GRU, and sequence-to-sequence translation models implemented with LSTM and LSTM with Attention. It also details a from-scratch implementation of Transformers and a high-performing BERT-based text classification model using Huggingface, which achieved a top leaderboard score through fine-tuning and rigorous evaluation.',
#   'text': "## Natural Language Processing (NLP):\n\n- Text classification using TFIDF (https://colab.research.google.com/drive/19Jl8nvJL5kZ84d2qRi3VwwDMY2WL4ZIS?usp=sharing): The goal of this project is to develop a machine learning model that can accurately classify tweets as either related to real disasters or not.\n- Text Classification with GloVe and LSTM (https://colab.research.google.com/drive/1W6kHzMh7iX5y6JZV731teVVRKyyMpg_u?usp=sharing): This project employs LSTM neural networks for text classification on disaster-related messages. It preprocesses and tokenizes text data, utilizes pre-trained word embeddings, and trains the model with Keras. Finally, it evaluates the model's performance, generates predictions, and creates a submission file for Kaggle competition.\n\n- Text Generation with GRU (https://colab.research.google.com/drive/1mixPpl1DGjgSGhu2xYTx4Jyd4p1NHrjs?usp=sharing): This code employs TensorFlow and Keras to build a text generation model. It preprocesses Shakespearean text data, creating sequences for training. The model architecture includes an Embedding layer and a GRU layer. After training, the model can generate text based on given starting seeds. This approach facilitates the generation of coherent text sequences.\n\n- Seq2seq Translation model with LSTM implementation (https://colab.research.google.com/drive/1Ffq3WFRfRFoo-CNLidxCDbtO4jFEwcp0?usp=sharing)\n\n- Seq2seq Translation model with LSTM + Attention implementation (https://colab.research.google.com/drive/1B?tMIEDccE4WGBhwci-ylqXADdu_oXav?usp=sharing)\n\n- Transformers Implementation From scratch (https://colab.research.google.com/drive/1YqtJlJrpaPWtKueitdSCLb1v7tLYhqPZ?usp=sharing)\n\n- Text Classification With BERT huggingface (https://www.kaggle.com/code/abdalrahminmohammed/bert-fine-tuning-with-huggingface): -Leaderboard Score: 0.99872 (first in the Leaderboard)\n\n- Loaded the pre-trained distillery-base-uncased model for sequence classification.\n- Set up training arguments and fine-tuned the model using a Trainer object.\n- Trained the model on the tokenized datasets and evaluated it using accuracy and F1 score metrics.\n- Predicted on the validation set in batches, calculated evaluation metrics (confusion matrix, classification report, F1 score).\n- Achieved high accuracy and F1 score on the validation set, indicating a well-performing model.\n"}}

# %%
target_docs = [{
    "doc_index": 0,
    "target_ids": [ "0007"]
},

{
    "doc_index":1,
    "target_ids": ["0002" , "0004"]
},


]

# %%
target_docs[0]
# Out:
# {'doc_index': 0, 'target_ids': ['0007']}

# %%
docs_list
# Out:
# {'documents': [{'id': 'pi-cmnnmjex1016w01qv2ej4ay36',
#    'name': 'projects_portfolio_in_github.pdf',
#    'description': 'This document outlines a data science portfolio showcasing projects in data analysis, visualization, machine learning, recommendation systems, time series forecasting, deep learning, and natural language processing.',
#    'status': 'completed',
#    'createdAt': '2026-04-06T20:09:43.265000',
#    'pageNum': 5,
#    'folderId': None},
#   {'id': 'pi-cmnnmjdi9016t01qvslbcf577',
#    'name': 'my_Linkedin.pdf',
#    'description': 'This document outlines the experience of Abdelrahman Mohamed, an AI Engineer specializing in LLM agents, RAG pipelines, and real-time AI assistants, with roles at Electro Pi, Sand Technologies, and ALX Arabia.',
#    'status': 'completed',
#    'createdAt': '2026-04-06T20:09:41.437000',
#    'pageNum': 4,
#    'folderId': None},
#   {'id': 'pi-cmnnmjcdr016q01qvn3cwv3ub',
#    'name': 'Abdelrahman_Mohamed_CV_14.9_1.pdf',
#    'description': 'This document is a resume for Abdelrahman Mohamed, an AI/ML Engineer with experience in GenAI systems, LLM fine-tuning, RAG pipelines, and real-time voice assistants, with a focus on Arabic AI applications.',
#    'status': 'completed',
#    'createdAt': '2026-04-06T20:09:39.983000',
#    'pageNum': 2,
#    'folderId': None}],
#  'total': 3,
#  'limit': 50,
#  'offset': 0}

# %%
def build_all_indexes(pi_client, docs_list):
    all_indexes = {}

    for i, doc in enumerate(docs_list.get("documents", [])):
        doc_id = doc["id"]

        tree_result = pi_client.get_tree(doc_id, node_summary=True)
        nodes = tree_result.get("result", [])

        all_indexes[i] = build_index(nodes)  # store index per doc

    return all_indexes

# %%
all_indexes = build_all_indexes(pi_client, docs_list)

# %%
all_indexes
# Out:
# {0: {'0000': {'title': 'Data Science Portfolio',
#    'node_id': '0000',
#    'page_index': 1,
#    'summary': '# Data Science Portfolio\n',
#    'text': '# Data Science Portfolio\n'},
#   '0001': {'title': 'Skill Based Projects',
#    'node_id': '0001',
#    'page_index': 2,
#    'prefix_summary': '# Skill Based Projects\n',
#    'text': '# Skill Based Projects\n',
#    'nodes': [{'title': 'Data Analysis and Visualization:',
#      'node_id': '0002',
#      'page_index': 2,
#      'summary': 'The text describes four data analysis and visualization projects: an EDA on Airbnb listings to understand demand trends; an analysis of electronics store sales data; a startup growth analysis with a focus on location, marketing, and revenue, including dashboard creation; and a project to track water funds for Maji Ndogo, emphasizing transparency and accountability by comparing budgets, project completion, team performance, and costs.',
#      'text': "## Data Analysis and Visualization:\n\n- Airbnb-Listing-EDA (https://github.com/Veto2922/Airbnb-Listing-EDA): This project involves performing an exploratory data analysis (EDA) on Airbnb listing data for a particular city. The analysis focuses on factors such as price, availability, location, and property type to identify trends and patterns in the demand for Airbnb listings in the city. The project includes data cleaning, visualization, and statistical analysis.\n- Electronics store sales EDA (https://github.com/Veto2922/My-data-analysis-projects/tree/main/project1_Finance%20Problem): In this data analysis project, I took on the challenge of exploring 12 months' worth of sales data for an electronics store. The dataset included a vast array of purchase information, including product types, costs, purchase addresses, and more.\n- Startup expansion (https://github.com/Veto2922/My-data-analysis-projects/tree/main/project3_startup-expansion): In this project, I worked with a comprehensive dataset that provided valuable insights into the dynamics of startup growth, covering key aspects such as location, marketing spending, and revenue. and I made a Dashboard and Report To ensure that the project's insights were easily digestible\n- tracking Maji Ndogo's water funds (Power B0 (https://github.com/Veto2922/EXPLORE-AI-Integrated-project-Transparency-in-tracking-Maji-Ndogo-s-water-funds): Our mission is to communicate with transparency: Where did the money go? We will track the total budget against project completion, monitor teams' performance, and compare budgeted versus actual costs to flag potential corruption, promoting transparency and accountability in addressing Maji Ndogo's water crisis.\n"},
#     {'title': 'Machine Learning:',
#      'node_id': '0003',
#      'page_index': 3,
#      'summary': "## Machine Learning:\n\n- FastML With EDA python package (My own package) (https://github.com/Veto2922/Fast-Machine-Learning-With-EDA-python-package/tree/main/FastML_With_EDA): FastML_With_EDA is a versatile Python package designed to simplify the machine learning pipeline, from exploratory data analysis (EDA) and preprocessing to automated machine learning (AutoML) model training and evaluation. Whether you're a beginner or an experienced data scientist, FastML provides the tools you need to streamline your workflow and make data-driven decisions.\n- I also created a WEB APP (https://github.com/Veto2922/streamlit_app_for_FastML_With_EDA_python_package/tree/main) as GUI for this package\n",
#      'text': "## Machine Learning:\n\n- FastML With EDA python package (My own package) (https://github.com/Veto2922/Fast-Machine-Learning-With-EDA-python-package/tree/main/FastML_With_EDA): FastML_With_EDA is a versatile Python package designed to simplify the machine learning pipeline, from exploratory data analysis (EDA) and preprocessing to automated machine learning (AutoML) model training and evaluation. Whether you're a beginner or an experienced data scientist, FastML provides the tools you need to streamline your workflow and make data-driven decisions.\n- I also created a WEB APP (https://github.com/Veto2922/streamlit_app_for_FastML_With_EDA_python_package/tree/main) as GUI for this package\n"},
#     {'title': 'Recommendation System',
#      'node_id': '0004',
#      'page_index': 3,
#      'summary': '## Recommendation System\n\n- Rank and Knowledge base (https://github.com/Veto2922/Recommendation-system-course/tree/main/Task%201%20Rank-Based%2BKnowledge-Based%20Recommendations)\n- Content based (https://github.com/Veto2922/Movie-Recommender-System-content-based-)\n- Hybrid-based Book Recommendation System (https://github.com/Veto2922/hybrid-based-book-recommender-systems)\n',
#      'text': '## Recommendation System\n\n- Rank and Knowledge base (https://github.com/Veto2922/Recommendation-system-course/tree/main/Task%201%20Rank-Based%2BKnowledge-Based%20Recommendations)\n- Content based (https://github.com/Veto2922/Movie-Recommender-System-content-based-)\n- Hybrid-based Book Recommendation System (https://github.com/Veto2922/hybrid-based-book-recommender-systems)\n'},
#     {'title': 'Time series analysis and forecast',
#      'node_id': '0005',
#      'page_index': 3,
#      'summary': '## Time series analysis and forecast\n\n- Monthly Retail Sales Forecasting (https://github.com/Veto2922/Advance-Monthly-Retail-Sales-Forecasting): This project involves forecasting the monthly sales for clothing and clothing accessory stores using LSTM (Long Short-Term Memory) neural networks. The dataset consists of monthly sales data (in millions of dollars, not seasonally adjusted) retrieved from the FRED, Federal Reserve Bank of St. Louis.\n- Time series forecasting using LSTM (https://github.com/Veto2922/Time-series-forecasting-using-LSTM/tree/main)\n',
#      'text': '## Time series analysis and forecast\n\n- Monthly Retail Sales Forecasting (https://github.com/Veto2922/Advance-Monthly-Retail-Sales-Forecasting): This project involves forecasting the monthly sales for clothing and clothing accessory stores using LSTM (Long Short-Term Memory) neural networks. The dataset consists of monthly sales data (in millions of dollars, not seasonally adjusted) retrieved from the FRED, Federal Reserve Bank of St. Louis.\n- Time series forecasting using LSTM (https://github.com/Veto2922/Time-series-forecasting-using-LSTM/tree/main)\n'},
#     {'title': 'Deep Learning:',
#      'node_id': '0006',
#      'page_index': 3,
#      'summary': 'The text covers an introduction to Deep Learning and Artificial Neural Networks (ANN). It then details three projects utilizing TensorFlow and Keras: a regression project for housing price prediction involving data analysis and model building; a classification project for breast cancer diagnosis prediction that includes feature selection, data preprocessing, and overfitting mitigation techniques; and a deep learning project for predicting loan default on LendingClub data, focusing on historical loan features and loan status.',
#      'text': '## Deep Learning:\n\nANN\n\n- Tanserflow and keras regression (https://colab.research.google.com/drive/1iuFkq_R-8jfBVDSdLUDOOnvSf16mG5D1?usp=sharing): This project analyzes housing data using Pandas, NumPy, and TensorFlow &amp; keras. It explores data distribution, geographical properties, and performs feature engineering. A neural network model is built, trained, and evaluated for predicting house prices, achieving insights and predictions.\n- Tanserflow and keras classification (https://colab.research.google.com/drive/169CJUosBsreu5rS-qFrAi39mTyu7nvP2?usp=sharing): The project conducts t-tests on each feature to assess its significance in predicting a binary target variable (breast cancer diagnosis). It then selects features with p-values below a significance level (0.05). The data is split into training and testing sets, scaled, and used to train a neural network model. And addresses overfitting by implementing early stopping and dropout techniques in the neural network model\n- LendingClub Loan Default Prediction (https://drive.google.com/file/d/1f6csdAqDWvsNOUik-RGMIGmyq7nelqJ5/view?usp=sharing): This project aims to build a Deep learning model to predict whether a borrower will repay their loan based on historical loan data from LendingClub. LendingClub is a peer-to-peer lending platform that facilitates loan origination by connecting borrowers with investors. The dataset includes various features such as loan amount, interest rate, borrower employment details, and credit history. The main target variable for prediction is loan_status, which indicates if a loan was "Fully Paid" or "Charged Off" (defaulted).\n'},
#     {'title': 'Natural Language Processing (NLP):',
#      'node_id': '0007',
#      'page_index': 4,
#      'summary': 'The text covers various Natural Language Processing (NLP) techniques and projects. These include text classification using TFIDF and GloVe with LSTM for disaster-related content, text generation with GRU, and sequence-to-sequence translation models implemented with LSTM and LSTM with Attention. It also details a from-scratch implementation of Transformers and a high-performing BERT-based text classification model using Huggingface, which achieved a top leaderboard score through fine-tuning and rigorous evaluation.',
#      'text': "## Natural Language Processing (NLP):\n\n- Text classification using TFIDF (https://colab.research.google.com/drive/19Jl8nvJL5kZ84d2qRi3VwwDMY2WL4ZIS?usp=sharing): The goal of this project is to develop a machine learning model that can accurately classify tweets as either related to real disasters or not.\n- Text Classification with GloVe and LSTM (https://colab.research.google.com/drive/1W6kHzMh7iX5y6JZV731teVVRKyyMpg_u?usp=sharing): This project employs LSTM neural networks for text classification on disaster-related messages. It preprocesses and tokenizes text data, utilizes pre-trained word embeddings, and trains the model with Keras. Finally, it evaluates the model's performance, generates predictions, and creates a submission file for Kaggle competition.\n\n- Text Generation with GRU (https://colab.research.google.com/drive/1mixPpl1DGjgSGhu2xYTx4Jyd4p1NHrjs?usp=sharing): This code employs TensorFlow and Keras to build a text generation model. It preprocesses Shakespearean text data, creating sequences for training. The model architecture includes an Embedding layer and a GRU layer. After training, the model can generate text based on given starting seeds. This approach facilitates the generation of coherent text sequences.\n\n- Seq2seq Translation model with LSTM implementation (https://colab.research.google.com/drive/1Ffq3WFRfRFoo-CNLidxCDbtO4jFEwcp0?usp=sharing)\n\n- Seq2seq Translation model with LSTM + Attention implementation (https://colab.research.google.com/drive/1B?tMIEDccE4WGBhwci-ylqXADdu_oXav?usp=sharing)\n\n- Transformers Implementation From scratch (https://colab.research.google.com/drive/1YqtJlJrpaPWtKueitdSCLb1v7tLYhqPZ?usp=sharing)\n\n- Text Classification With BERT huggingface (https://www.kaggle.com/code/abdalrahminmohammed/bert-fine-tuning-with-huggingface): -Leaderboard Score: 0.99872 (first in the Leaderboard)\n\n- Loaded the pre-trained distillery-base-uncased model for sequence classification.\n- Set up training arguments and fine-tuned the model using a Trainer object.\n- Trained the model on the tokenized datasets and evaluated it using accuracy and F1 score metrics.\n- Predicted on the validation set in batches, calculated evaluation metrics (confusion matrix, classification report, F1 score).\n- Achieved high accuracy and F1 score on the validation set, indicating a well-performing model.\n"}]},
#   '0002': {'title': 'Data Analysis and Visualization:',
#    'node_id': '0002',
#    'page_index': 2,
#    'summary': 'The text describes four data analysis and visualization projects: an EDA on Airbnb listings to understand demand trends; an analysis of electronics store sales data; a startup growth analysis with a focus on location, marketing, and revenue, including dashboard creation; and a project to track water funds for Maji Ndogo, emphasizing transparency and accountability by comparing budgets, project completion, team performance, and costs.',
#    'text': "## Data Analysis and Visualization:\n\n- Airbnb-Listing-EDA (https://github.com/Veto2922/Airbnb-Listing-EDA): This project involves performing an exploratory data analysis (EDA) on Airbnb listing data for a particular city. The analysis focuses on factors such as price, availability, location, and property type to identify trends and patterns in the demand for Airbnb listings in the city. The project includes data cleaning, visualization, and statistical analysis.\n- Electronics store sales EDA (https://github.com/Veto2922/My-data-analysis-projects/tree/main/project1_Finance%20Problem): In this data analysis project, I took on the challenge of exploring 12 months' worth of sales data for an electronics store. The dataset included a vast array of purchase information, including product types, costs, purchase addresses, and more.\n- Startup expansion (https://github.com/Veto2922/My-data-analysis-projects/tree/main/project3_startup-expansion): In this project, I worked with a comprehensive dataset that provided valuable insights into the dynamics of startup growth, covering key aspects such as location, marketing spending, and revenue. and I made a Dashboard and Report To ensure that the project's insights were easily digestible\n- tracking Maji Ndogo's water funds (Power B0 (https://github.com/Veto2922/EXPLORE-AI-Integrated-project-Transparency-in-tracking-Maji-Ndogo-s-water-funds): Our mission is to communicate with transparency: Where did the money go? We will track the total budget against project completion, monitor teams' performance, and compare budgeted versus actual costs to flag potential corruption, promoting transparency and accountability in addressing Maji Ndogo's water crisis.\n"},
#   '0003': {'title': 'Machine Learning:',
#    'node_id': '0003',
#    'page_index': 3,
#    'summary': "## Machine Learning:\n\n- FastML With EDA python package (My own package) (https://github.com/Veto2922/Fast-Machine-Learning-With-EDA-python-package/tree/main/FastML_With_EDA): FastML_With_EDA is a versatile Python package designed to simplify the machine learning pipeline, from exploratory data analysis (EDA) and preprocessing to automated machine learning (AutoML) model training and evaluation. Whether you're a beginner or an experienced data scientist, FastML provides the tools you need to streamline your workflow and make data-driven decisions.\n- I also created a WEB APP (https://github.com/Veto2922/streamlit_app_for_FastML_With_EDA_python_package/tree/main) as GUI for this package\n",
#    'text': "## Machine Learning:\n\n- FastML With EDA python package (My own package) (https://github.com/Veto2922/Fast-Machine-Learning-With-EDA-python-package/tree/main/FastML_With_EDA): FastML_With_EDA is a versatile Python package designed to simplify the machine learning pipeline, from exploratory data analysis (EDA) and preprocessing to automated machine learning (AutoML) model training and evaluation. Whether you're a beginner or an experienced data scientist, FastML provides the tools you need to streamline your workflow and make data-driven decisions.\n- I also created a WEB APP (https://github.com/Veto2922/streamlit_app_for_FastML_With_EDA_python_package/tree/main) as GUI for this package\n"},
#   '0004': {'title': 'Recommendation System',
#    'node_id': '0004',
#    'page_index': 3,
#    'summary': '## Recommendation System\n\n- Rank and Knowledge base (https://github.com/Veto2922/Recommendation-system-course/tree/main/Task%201%20Rank-Based%2BKnowledge-Based%20Recommendations)\n- Content based (https://github.com/Veto2922/Movie-Recommender-System-content-based-)\n- Hybrid-based Book Recommendation System (https://github.com/Veto2922/hybrid-based-book-recommender-systems)\n',
#    'text': '## Recommendation System\n\n- Rank and Knowledge base (https://github.com/Veto2922/Recommendation-system-course/tree/main/Task%201%20Rank-Based%2BKnowledge-Based%20Recommendations)\n- Content based (https://github.com/Veto2922/Movie-Recommender-System-content-based-)\n- Hybrid-based Book Recommendation System (https://github.com/Veto2922/hybrid-based-book-recommender-systems)\n'},
#   '0005': {'title': 'Time series analysis and forecast',
#    'node_id': '0005',
#    'page_index': 3,
#    'summary': '## Time series analysis and forecast\n\n- Monthly Retail Sales Forecasting (https://github.com/Veto2922/Advance-Monthly-Retail-Sales-Forecasting): This project involves forecasting the monthly sales for clothing and clothing accessory stores using LSTM (Long Short-Term Memory) neural networks. The dataset consists of monthly sales data (in millions of dollars, not seasonally adjusted) retrieved from the FRED, Federal Reserve Bank of St. Louis.\n- Time series forecasting using LSTM (https://github.com/Veto2922/Time-series-forecasting-using-LSTM/tree/main)\n',
#    'text': '## Time series analysis and forecast\n\n- Monthly Retail Sales Forecasting (https://github.com/Veto2922/Advance-Monthly-Retail-Sales-Forecasting): This project involves forecasting the monthly sales for clothing and clothing accessory stores using LSTM (Long Short-Term Memory) neural networks. The dataset consists of monthly sales data (in millions of dollars, not seasonally adjusted) retrieved from the FRED, Federal Reserve Bank of St. Louis.\n- Time series forecasting using LSTM (https://github.com/Veto2922/Time-series-forecasting-using-LSTM/tree/main)\n'},
#   '0006': {'title': 'Deep Learning:',
#    'node_id': '0006',
#    'page_index': 3,
#    'summary': 'The text covers an introduction to Deep Learning and Artificial Neural Networks (ANN). It then details three projects utilizing TensorFlow and Keras: a regression project for housing price prediction involving data analysis and model building; a classification project for breast cancer diagnosis prediction that includes feature selection, data preprocessing, and overfitting mitigation techniques; and a deep learning project for predicting loan default on LendingClub data, focusing on historical loan features and loan status.',
#    'text': '## Deep Learning:\n\nANN\n\n- Tanserflow and keras regression (https://colab.research.google.com/drive/1iuFkq_R-8jfBVDSdLUDOOnvSf16mG5D1?usp=sharing): This project analyzes housing data using Pandas, NumPy, and TensorFlow &amp; keras. It explores data distribution, geographical properties, and performs feature engineering. A neural network model is built, trained, and evaluated for predicting house prices, achieving insights and predictions.\n- Tanserflow and keras classification (https://colab.research.google.com/drive/169CJUosBsreu5rS-qFrAi39mTyu7nvP2?usp=sharing): The project conducts t-tests on each feature to assess its significance in predicting a binary target variable (breast cancer diagnosis). It then selects features with p-values below a significance level (0.05). The data is split into training and testing sets, scaled, and used to train a neural network model. And addresses overfitting by implementing early stopping and dropout techniques in the neural network model\n- LendingClub Loan Default Prediction (https://drive.google.com/file/d/1f6csdAqDWvsNOUik-RGMIGmyq7nelqJ5/view?usp=sharing): This project aims to build a Deep learning model to predict whether a borrower will repay their loan based on historical loan data from LendingClub. LendingClub is a peer-to-peer lending platform that facilitates loan origination by connecting borrowers with investors. The dataset includes various features such as loan amount, interest rate, borrower employment details, and credit history. The main target variable for prediction is loan_status, which indicates if a loan was "Fully Paid" or "Charged Off" (defaulted).\n'},
#   '0007': {'title': 'Natural Language Processing (NLP):',
#    'node_id': '0007',
#    'page_index': 4,
#    'summary': 'The text covers various Natural Language Processing (NLP) techniques and projects. These include text classification using TFIDF and GloVe with LSTM for disaster-related content, text generation with GRU, and sequence-to-sequence translation models implemented with LSTM and LSTM with Attention. It also details a from-scratch implementation of Transformers and a high-performing BERT-based text classification model using Huggingface, which achieved a top leaderboard score through fine-tuning and rigorous evaluation.',
#    'text': "## Natural Language Processing (NLP):\n\n- Text classification using TFIDF (https://colab.research.google.com/drive/19Jl8nvJL5kZ84d2qRi3VwwDMY2WL4ZIS?usp=sharing): The goal of this project is to develop a machine learning model that can accurately classify tweets as either related to real disasters or not.\n- Text Classification with GloVe and LSTM (https://colab.research.google.com/drive/1W6kHzMh7iX5y6JZV731teVVRKyyMpg_u?usp=sharing): This project employs LSTM neural networks for text classification on disaster-related messages. It preprocesses and tokenizes text data, utilizes pre-trained word embeddings, and trains the model with Keras. Finally, it evaluates the model's performance, generates predictions, and creates a submission file for Kaggle competition.\n\n- Text Generation with GRU (https://colab.research.google.com/drive/1mixPpl1DGjgSGhu2xYTx4Jyd4p1NHrjs?usp=sharing): This code employs TensorFlow and Keras to build a text generation model. It preprocesses Shakespearean text data, creating sequences for training. The model architecture includes an Embedding layer and a GRU layer. After training, the model can generate text based on given starting seeds. This approach facilitates the generation of coherent text sequences.\n\n- Seq2seq Translation model with LSTM implementation (https://colab.research.google.com/drive/1Ffq3WFRfRFoo-CNLidxCDbtO4jFEwcp0?usp=sharing)\n\n- Seq2seq Translation model with LSTM + Attention implementation (https://colab.research.google.com/drive/1B?tMIEDccE4WGBhwci-ylqXADdu_oXav?usp=sharing)\n\n- Transformers Implementation From scratch (https://colab.research.google.com/drive/1YqtJlJrpaPWtKueitdSCLb1v7tLYhqPZ?usp=sharing)\n\n- Text Classification With BERT huggingface (https://www.kaggle.com/code/abdalrahminmohammed/bert-fine-tuning-with-huggingface): -Leaderboard Score: 0.99872 (first in the Leaderboard)\n\n- Loaded the pre-trained distillery-base-uncased model for sequence classification.\n- Set up training arguments and fine-tuned the model using a Trainer object.\n- Trained the model on the tokenized datasets and evaluated it using accuracy and F1 score metrics.\n- Predicted on the validation set in batches, calculated evaluation metrics (confusion matrix, classification report, F1 score).\n- Achieved high accuracy and F1 score on the validation set, indicating a well-performing model.\n"}},
#  1: {'0000': {'title': 'Abdelrahman Mohamed',
#    'node_id': '0000',
#    'page_index': 1,
#    'prefix_summary': '# Abdelrahman Mohamed\nAI Engineer @ Electro Pi | Specializing in ML, NLP, and LLMs | Build AI Agents &amp; Automations | Helping Startups Automate with LLMs\nCairo, Egypt\n',
#    'text': '# Abdelrahman Mohamed\nAI Engineer @ Electro Pi | Specializing in ML, NLP, and LLMs | Build AI Agents &amp; Automations | Helping Startups Automate with LLMs\nCairo, Egypt\n',
#    'nodes': [{'title': 'Summary',
#      'node_id': '0001',
#      'page_index': 1,
#      'summary': "## Summary\nI'm an AI Engineer passionate about building practical GenAI solutions. I work on real-world applications involving LLM agents, RAG pipelines, and real-time AI assistants.\n",
#      'text': "## Summary\nI'm an AI Engineer passionate about building practical GenAI solutions. I work on real-world applications involving LLM agents, RAG pipelines, and real-time AI assistants.\n"},
#     {'title': 'Experience',
#      'node_id': '0002',
#      'page_index': 1,
#      'prefix_summary': 'This text details the experience of an AI Engineer at Electro Pi, focusing on the development and enhancement of AI systems. Key contributions include building a decision-making system with LLMs and advanced prompt engineering for financial reasoning, integrating RAG for dynamic financial chart generation, refactoring automation pipelines for improved maintainability, developing an AI sales agent with real-time recommendations and monitoring, contributing to voice agent systems for conversational AI, and working on computer vision projects for manufacturing defect detection.',
#      'text': '## Experience\nElectro Pi\n1 year 8 months\n\nAI Engineer\nSeptember 2024 - Present (1 year 7 months)\nCairo, Egypt\n\n- Developed a modular decision-making system using 7 LLMs, incorporating session-based memory management (short/long-term) and advanced prompt engineering. Achieved 99% accuracy in financial reasoning and reduced average response time from 1 minute to 10 seconds.\n\n- Integrated Retrieval-Augmented Generation (RAG) to inject contextual financial regulations into LLM prompts, enabling dynamic generation of advanced financial charts and graphs with high relevance.\n\n- Refactored core components of the automation pipeline using OOP, SOLID principles, and best practices, reducing average code file size from 500+ lines to under 75 lines, significantly improving readability and maintainability.\n\n- Developed an AI sales agent for a cosmetics platform using LangGraph, enabling real-time product recommendations via live API calls. Improved system response time by  $\\sim 40\\%$  and integrated monitoring tools (Prometheus, Grafana) within a Dockerized CI/CD pipeline.\n\n- Contributed to voice agent systems using Gemini Live API and LiveKit with WebRTC, supporting real-time conversation flows and intelligent responses.\n\n- Contributed to computer vision projects for manufacturing safety and quality assurance, including image annotation, model training, and fine-tuning for real-time defect detection.\n',
#      'nodes': [{'title': 'AI Engineer',
#        'node_id': '0003',
#        'page_index': 2,
#        'summary': '### AI Engineer\n\nAugust 2024 - September 2024 (2 months)\n\nCairo, Egypt\n\n- Contributed to real-world AI projects, including harmful prompt detection and RAG-powered AI assistance using LangChain.\n- Worked on an AI-driven platform designed to help companies manage finances more efficiently, leveraging LLMs and machine learning models.\n- Playedakeyrole in integrating LLMs with financial models to process JSON data from Excel files, enabling automated extraction and calculation of financial insights based on user queries.\n',
#        'text': '### AI Engineer\n\nAugust 2024 - September 2024 (2 months)\n\nCairo, Egypt\n\n- Contributed to real-world AI projects, including harmful prompt detection and RAG-powered AI assistance using LangChain.\n- Worked on an AI-driven platform designed to help companies manage finances more efficiently, leveraging LLMs and machine learning models.\n- Playedakeyrole in integrating LLMs with financial models to process JSON data from Excel files, enabling automated extraction and calculation of financial insights based on user queries.\n'},
#       {'title': 'Sand Technologies',
#        'node_id': '0004',
#        'page_index': 2,
#        'summary': '### Sand Technologies\n\nData Scientist &amp; AI Engineer\n\nSeptember 2024 - Present (1 year 7 months)\n\nAssist startups in harnessing data and integrating AI and LLMs into their projects.\n',
#        'text': '### Sand Technologies\n\nData Scientist &amp; AI Engineer\n\nSeptember 2024 - Present (1 year 7 months)\n\nAssist startups in harnessing data and integrating AI and LLMs into their projects.\n'},
#       {'title': 'ALX Arabia',
#        'node_id': '0005',
#        'page_index': 2,
#        'summary': '### ALX Arabia\n\nScholarship\n\nMay 2023 - September 2024 (1 year 5 months)\n\nCairo, Egypt\n\nThis scholarship consists of 3 months of soft skills and approximately 11 months of studying data science from the Explore AI Academy curriculum.\n',
#        'text': '### ALX Arabia\n\nScholarship\n\nMay 2023 - September 2024 (1 year 5 months)\n\nCairo, Egypt\n\nThis scholarship consists of 3 months of soft skills and approximately 11 months of studying data science from the Explore AI Academy curriculum.\n'},
#       {'title': 'AI Rahma Medical Center',
#        'node_id': '0006',
#        'page_index': 3,
#        'prefix_summary': '### AI Rahma Medical Center\n',
#        'text': '### AI Rahma Medical Center\n',
#        'nodes': [{'title': 'Data Analyst',
#          'node_id': '0007',
#          'page_index': 3,
#          'summary': "The text details a Data Analyst role at Al-Rahma Medical Center where the individual was responsible for data transformation, cleaning, and dashboard development to support strategic decision-making for the medical center and its pharmacies. It also lists two Machine Learning Intern positions at SYNC INTERN'S and ApplAi, and educational background in Electrical, Electronics and Communications Engineering from CIC and a Data Science scholarship from ExploreAI Academy.",
#          'text': "#### Data Analyst\n\nJune 2023 - September 2023 (4 months)\n\nCairo, Egypt\n\nAs a dedicated Data Analyst at Al-Rahma Medical Center, I played a pivotal role in driving data-driven decision-making for both the medical center and its eight affiliated pharmacies. Leveraging my expertise in data management and analytics, I contributed significantly to the growth and operational efficiency of the center.\n\nKey Achievements:\n\nData Transformation and Cleaning:\n\n- Successfully extracted and transformed data from the B-Connect program for pharmacy management, ensuring accuracy and consistency.\n- Utilized Excel to convert raw data into a comprehensive and organized format, laying the foundation for insightful analysis.\n\n# Data Preparation for Analysis:\n\n- Meticulously prepared and cleaned data sets, enhancing the quality of information available for analysis.\n- Conducted data conversion processes to facilitate seamless integration and interpretation, ensuring data readiness for in-depth analysis.\n\nDashboard Development:\n\n- Engineered a series of dynamic dashboards for both the medical center and each affiliated pharmacy, providing stakeholders with real-time insights into performance metrics.\n- These dashboards spanned a comprehensive view of the past five years, enabling informed decision-making and strategic planning.\n\nStrategic Decision Support:\n\n- Empowered decision-makers with actionable insights, facilitating strategic planning and growth initiatives for the center and affiliated pharmacies.\n- Collaborated closely with cross-functional teams to align data analytics with business objectives, ensuring data-driven decisions at every level.\n\nPage 3 of 4\n\nPage 4 of 4\n\nSYNC INTERN'S\nMachine Learning Intern\nApril 2023 - May 2023 (2 months)\n\nApplAi\nMachine Learning Intern\nJanuary 2023 - February 2023 (2 months)\nAin shames university\n\n---\n\nEducation\n\nCIC - Canadian International College\nElectrical, Electronics and Communications Engineering · (2018 - 2023)\n\nExploreAI Academy\nScholarship, Data science · (May 2023 - July 2024)\n"}]}]}]},
#   '0001': {'title': 'Summary',
#    'node_id': '0001',
#    'page_index': 1,
#    'summary': "## Summary\nI'm an AI Engineer passionate about building practical GenAI solutions. I work on real-world applications involving LLM agents, RAG pipelines, and real-time AI assistants.\n",
#    'text': "## Summary\nI'm an AI Engineer passionate about building practical GenAI solutions. I work on real-world applications involving LLM agents, RAG pipelines, and real-time AI assistants.\n"},
#   '0002': {'title': 'Experience',
#    'node_id': '0002',
#    'page_index': 1,
#    'prefix_summary': 'This text details the experience of an AI Engineer at Electro Pi, focusing on the development and enhancement of AI systems. Key contributions include building a decision-making system with LLMs and advanced prompt engineering for financial reasoning, integrating RAG for dynamic financial chart generation, refactoring automation pipelines for improved maintainability, developing an AI sales agent with real-time recommendations and monitoring, contributing to voice agent systems for conversational AI, and working on computer vision projects for manufacturing defect detection.',
#    'text': '## Experience\nElectro Pi\n1 year 8 months\n\nAI Engineer\nSeptember 2024 - Present (1 year 7 months)\nCairo, Egypt\n\n- Developed a modular decision-making system using 7 LLMs, incorporating session-based memory management (short/long-term) and advanced prompt engineering. Achieved 99% accuracy in financial reasoning and reduced average response time from 1 minute to 10 seconds.\n\n- Integrated Retrieval-Augmented Generation (RAG) to inject contextual financial regulations into LLM prompts, enabling dynamic generation of advanced financial charts and graphs with high relevance.\n\n- Refactored core components of the automation pipeline using OOP, SOLID principles, and best practices, reducing average code file size from 500+ lines to under 75 lines, significantly improving readability and maintainability.\n\n- Developed an AI sales agent for a cosmetics platform using LangGraph, enabling real-time product recommendations via live API calls. Improved system response time by  $\\sim 40\\%$  and integrated monitoring tools (Prometheus, Grafana) within a Dockerized CI/CD pipeline.\n\n- Contributed to voice agent systems using Gemini Live API and LiveKit with WebRTC, supporting real-time conversation flows and intelligent responses.\n\n- Contributed to computer vision projects for manufacturing safety and quality assurance, including image annotation, model training, and fine-tuning for real-time defect detection.\n',
#    'nodes': [{'title': 'AI Engineer',
#      'node_id': '0003',
#      'page_index': 2,
#      'summary': '### AI Engineer\n\nAugust 2024 - September 2024 (2 months)\n\nCairo, Egypt\n\n- Contributed to real-world AI projects, including harmful prompt detection and RAG-powered AI assistance using LangChain.\n- Worked on an AI-driven platform designed to help companies manage finances more efficiently, leveraging LLMs and machine learning models.\n- Playedakeyrole in integrating LLMs with financial models to process JSON data from Excel files, enabling automated extraction and calculation of financial insights based on user queries.\n',
#      'text': '### AI Engineer\n\nAugust 2024 - September 2024 (2 months)\n\nCairo, Egypt\n\n- Contributed to real-world AI projects, including harmful prompt detection and RAG-powered AI assistance using LangChain.\n- Worked on an AI-driven platform designed to help companies manage finances more efficiently, leveraging LLMs and machine learning models.\n- Playedakeyrole in integrating LLMs with financial models to process JSON data from Excel files, enabling automated extraction and calculation of financial insights based on user queries.\n'},
#     {'title': 'Sand Technologies',
#      'node_id': '0004',
#      'page_index': 2,
#      'summary': '### Sand Technologies\n\nData Scientist &amp; AI Engineer\n\nSeptember 2024 - Present (1 year 7 months)\n\nAssist startups in harnessing data and integrating AI and LLMs into their projects.\n',
#      'text': '### Sand Technologies\n\nData Scientist &amp; AI Engineer\n\nSeptember 2024 - Present (1 year 7 months)\n\nAssist startups in harnessing data and integrating AI and LLMs into their projects.\n'},
#     {'title': 'ALX Arabia',
#      'node_id': '0005',
#      'page_index': 2,
#      'summary': '### ALX Arabia\n\nScholarship\n\nMay 2023 - September 2024 (1 year 5 months)\n\nCairo, Egypt\n\nThis scholarship consists of 3 months of soft skills and approximately 11 months of studying data science from the Explore AI Academy curriculum.\n',
#      'text': '### ALX Arabia\n\nScholarship\n\nMay 2023 - September 2024 (1 year 5 months)\n\nCairo, Egypt\n\nThis scholarship consists of 3 months of soft skills and approximately 11 months of studying data science from the Explore AI Academy curriculum.\n'},
#     {'title': 'AI Rahma Medical Center',
#      'node_id': '0006',
#      'page_index': 3,
#      'prefix_summary': '### AI Rahma Medical Center\n',
#      'text': '### AI Rahma Medical Center\n',
#      'nodes': [{'title': 'Data Analyst',
#        'node_id': '0007',
#        'page_index': 3,
#        'summary': "The text details a Data Analyst role at Al-Rahma Medical Center where the individual was responsible for data transformation, cleaning, and dashboard development to support strategic decision-making for the medical center and its pharmacies. It also lists two Machine Learning Intern positions at SYNC INTERN'S and ApplAi, and educational background in Electrical, Electronics and Communications Engineering from CIC and a Data Science scholarship from ExploreAI Academy.",
#        'text': "#### Data Analyst\n\nJune 2023 - September 2023 (4 months)\n\nCairo, Egypt\n\nAs a dedicated Data Analyst at Al-Rahma Medical Center, I played a pivotal role in driving data-driven decision-making for both the medical center and its eight affiliated pharmacies. Leveraging my expertise in data management and analytics, I contributed significantly to the growth and operational efficiency of the center.\n\nKey Achievements:\n\nData Transformation and Cleaning:\n\n- Successfully extracted and transformed data from the B-Connect program for pharmacy management, ensuring accuracy and consistency.\n- Utilized Excel to convert raw data into a comprehensive and organized format, laying the foundation for insightful analysis.\n\n# Data Preparation for Analysis:\n\n- Meticulously prepared and cleaned data sets, enhancing the quality of information available for analysis.\n- Conducted data conversion processes to facilitate seamless integration and interpretation, ensuring data readiness for in-depth analysis.\n\nDashboard Development:\n\n- Engineered a series of dynamic dashboards for both the medical center and each affiliated pharmacy, providing stakeholders with real-time insights into performance metrics.\n- These dashboards spanned a comprehensive view of the past five years, enabling informed decision-making and strategic planning.\n\nStrategic Decision Support:\n\n- Empowered decision-makers with actionable insights, facilitating strategic planning and growth initiatives for the center and affiliated pharmacies.\n- Collaborated closely with cross-functional teams to align data analytics with business objectives, ensuring data-driven decisions at every level.\n\nPage 3 of 4\n\nPage 4 of 4\n\nSYNC INTERN'S\nMachine Learning Intern\nApril 2023 - May 2023 (2 months)\n\nApplAi\nMachine Learning Intern\nJanuary 2023 - February 2023 (2 months)\nAin shames university\n\n---\n\nEducation\n\nCIC - Canadian International College\nElectrical, Electronics and Communications Engineering · (2018 - 2023)\n\nExploreAI Academy\nScholarship, Data science · (May 2023 - July 2024)\n"}]}]},
#   '0003': {'title': 'AI Engineer',
#    'node_id': '0003',
#    'page_index': 2,
#    'summary': '### AI Engineer\n\nAugust 2024 - September 2024 (2 months)\n\nCairo, Egypt\n\n- Contributed to real-world AI projects, including harmful prompt detection and RAG-powered AI assistance using LangChain.\n- Worked on an AI-driven platform designed to help companies manage finances more efficiently, leveraging LLMs and machine learning models.\n- Playedakeyrole in integrating LLMs with financial models to process JSON data from Excel files, enabling automated extraction and calculation of financial insights based on user queries.\n',
#    'text': '### AI Engineer\n\nAugust 2024 - September 2024 (2 months)\n\nCairo, Egypt\n\n- Contributed to real-world AI projects, including harmful prompt detection and RAG-powered AI assistance using LangChain.\n- Worked on an AI-driven platform designed to help companies manage finances more efficiently, leveraging LLMs and machine learning models.\n- Playedakeyrole in integrating LLMs with financial models to process JSON data from Excel files, enabling automated extraction and calculation of financial insights based on user queries.\n'},
#   '0004': {'title': 'Sand Technologies',
#    'node_id': '0004',
#    'page_index': 2,
#    'summary': '### Sand Technologies\n\nData Scientist &amp; AI Engineer\n\nSeptember 2024 - Present (1 year 7 months)\n\nAssist startups in harnessing data and integrating AI and LLMs into their projects.\n',
#    'text': '### Sand Technologies\n\nData Scientist &amp; AI Engineer\n\nSeptember 2024 - Present (1 year 7 months)\n\nAssist startups in harnessing data and integrating AI and LLMs into their projects.\n'},
#   '0005': {'title': 'ALX Arabia',
#    'node_id': '0005',
#    'page_index': 2,
#    'summary': '### ALX Arabia\n\nScholarship\n\nMay 2023 - September 2024 (1 year 5 months)\n\nCairo, Egypt\n\nThis scholarship consists of 3 months of soft skills and approximately 11 months of studying data science from the Explore AI Academy curriculum.\n',
#    'text': '### ALX Arabia\n\nScholarship\n\nMay 2023 - September 2024 (1 year 5 months)\n\nCairo, Egypt\n\nThis scholarship consists of 3 months of soft skills and approximately 11 months of studying data science from the Explore AI Academy curriculum.\n'},
#   '0006': {'title': 'AI Rahma Medical Center',
#    'node_id': '0006',
#    'page_index': 3,
#    'prefix_summary': '### AI Rahma Medical Center\n',
#    'text': '### AI Rahma Medical Center\n',
#    'nodes': [{'title': 'Data Analyst',
#      'node_id': '0007',
#      'page_index': 3,
#      'summary': "The text details a Data Analyst role at Al-Rahma Medical Center where the individual was responsible for data transformation, cleaning, and dashboard development to support strategic decision-making for the medical center and its pharmacies. It also lists two Machine Learning Intern positions at SYNC INTERN'S and ApplAi, and educational background in Electrical, Electronics and Communications Engineering from CIC and a Data Science scholarship from ExploreAI Academy.",
#      'text': "#### Data Analyst\n\nJune 2023 - September 2023 (4 months)\n\nCairo, Egypt\n\nAs a dedicated Data Analyst at Al-Rahma Medical Center, I played a pivotal role in driving data-driven decision-making for both the medical center and its eight affiliated pharmacies. Leveraging my expertise in data management and analytics, I contributed significantly to the growth and operational efficiency of the center.\n\nKey Achievements:\n\nData Transformation and Cleaning:\n\n- Successfully extracted and transformed data from the B-Connect program for pharmacy management, ensuring accuracy and consistency.\n- Utilized Excel to convert raw data into a comprehensive and organized format, laying the foundation for insightful analysis.\n\n# Data Preparation for Analysis:\n\n- Meticulously prepared and cleaned data sets, enhancing the quality of information available for analysis.\n- Conducted data conversion processes to facilitate seamless integration and interpretation, ensuring data readiness for in-depth analysis.\n\nDashboard Development:\n\n- Engineered a series of dynamic dashboards for both the medical center and each affiliated pharmacy, providing stakeholders with real-time insights into performance metrics.\n- These dashboards spanned a comprehensive view of the past five years, enabling informed decision-making and strategic planning.\n\nStrategic Decision Support:\n\n- Empowered decision-makers with actionable insights, facilitating strategic planning and growth initiatives for the center and affiliated pharmacies.\n- Collaborated closely with cross-functional teams to align data analytics with business objectives, ensuring data-driven decisions at every level.\n\nPage 3 of 4\n\nPage 4 of 4\n\nSYNC INTERN'S\nMachine Learning Intern\nApril 2023 - May 2023 (2 months)\n\nApplAi\nMachine Learning Intern\nJanuary 2023 - February 2023 (2 months)\nAin shames university\n\n---\n\nEducation\n\nCIC - Canadian International College\nElectrical, Electronics and Communications Engineering · (2018 - 2023)\n\nExploreAI Academy\nScholarship, Data science · (May 2023 - July 2024)\n"}]},
#   '0007': {'title': 'Data Analyst',
#    'node_id': '0007',
#    'page_index': 3,
#    'summary': "The text details a Data Analyst role at Al-Rahma Medical Center where the individual was responsible for data transformation, cleaning, and dashboard development to support strategic decision-making for the medical center and its pharmacies. It also lists two Machine Learning Intern positions at SYNC INTERN'S and ApplAi, and educational background in Electrical, Electronics and Communications Engineering from CIC and a Data Science scholarship from ExploreAI Academy.",
#    'text': "#### Data Analyst\n\nJune 2023 - September 2023 (4 months)\n\nCairo, Egypt\n\nAs a dedicated Data Analyst at Al-Rahma Medical Center, I played a pivotal role in driving data-driven decision-making for both the medical center and its eight affiliated pharmacies. Leveraging my expertise in data management and analytics, I contributed significantly to the growth and operational efficiency of the center.\n\nKey Achievements:\n\nData Transformation and Cleaning:\n\n- Successfully extracted and transformed data from the B-Connect program for pharmacy management, ensuring accuracy and consistency.\n- Utilized Excel to convert raw data into a comprehensive and organized format, laying the foundation for insightful analysis.\n\n# Data Preparation for Analysis:\n\n- Meticulously prepared and cleaned data sets, enhancing the quality of information available for analysis.\n- Conducted data conversion processes to facilitate seamless integration and interpretation, ensuring data readiness for in-depth analysis.\n\nDashboard Development:\n\n- Engineered a series of dynamic dashboards for both the medical center and each affiliated pharmacy, providing stakeholders with real-time insights into performance metrics.\n- These dashboards spanned a comprehensive view of the past five years, enabling informed decision-making and strategic planning.\n\nStrategic Decision Support:\n\n- Empowered decision-makers with actionable insights, facilitating strategic planning and growth initiatives for the center and affiliated pharmacies.\n- Collaborated closely with cross-functional teams to align data analytics with business objectives, ensuring data-driven decisions at every level.\n\nPage 3 of 4\n\nPage 4 of 4\n\nSYNC INTERN'S\nMachine Learning Intern\nApril 2023 - May 2023 (2 months)\n\nApplAi\nMachine Learning Intern\nJanuary 2023 - February 2023 (2 months)\nAin shames university\n\n---\n\nEducation\n\nCIC - Canadian International College\nElectrical, Electronics and Communications Engineering · (2018 - 2023)\n\nExploreAI Academy\nScholarship, Data science · (May 2023 - July 2024)\n"}},
#  2: {'0000': {'title': 'Abdelrahman Mohamed',
#    'node_id': '0000',
#    'page_index': 1,
#    'prefix_summary': '# Abdelrahman Mohamed\n',
#    'text': '# Abdelrahman Mohamed\n',
#    'nodes': [{'title': 'AI/ML Engineer',
#      'node_id': '0001',
#      'page_index': 1,
#      'prefix_summary': '## AI/ML Engineer\n\nabdelrahman.m2922@gmail.com  +201099394113  Cairo, Egypt  abdelrahman-ai\n\nGitHub  Medium\n',
#      'text': '## AI/ML Engineer\n\nabdelrahman.m2922@gmail.com  +201099394113  Cairo, Egypt  abdelrahman-ai\n\nGitHub  Medium\n',
#      'nodes': [{'title': 'PROFESSIONAL SUMMARY',
#        'node_id': '0002',
#        'page_index': 1,
#        'summary': '### PROFESSIONAL SUMMARY\n\nAI Engineer experienced in real-world GenAI systems, from LLM fine-tuning and agentic workflows to RAG pipelines and real-time voice assistants. Strong ML and Python foundation, with a deep interest in advancing Arabic AI applications.\n',
# ...
#     {'title': 'SKILLS',
#      'node_id': '0011',
#      'page_index': 2,
#      'summary': '### SKILLS\n\nML/AI Frameworks — TensorFlow | PyTorch | Scikit-learn | Hugging Face | Transformers | LangChain | LangGraph | PEFT | BitsAndBytes | Unsloth | Ollama | vLLM\n\nNLP/GenAI — spaCy | NLTK | RAG | OpenAI | Gemini | Open-source LLMs | Embeddings\n\nDatabases — PostgreSQL | MySQL | MongoDB | Qdrant | FAISS | Chroma\n\nCloud &amp; DevOps — AWS | GCP | Docker | GitHub Actions\n\nAPIs &amp; Frameworks — FastAPI | Flask | Streamli | Gradio\n\nData Analysis — Pandas | NumPy | Matplotlib | Plotly | Power BI\n\nOther Tools — Prometheus | Grafana | Git/GitHub | Linux | Pytest | LiveKit | Pydantic | LangSmith\n',
#      'text': '### SKILLS\n\nML/AI Frameworks — TensorFlow | PyTorch | Scikit-learn | Hugging Face | Transformers | LangChain | LangGraph | PEFT | BitsAndBytes | Unsloth | Ollama | vLLM\n\nNLP/GenAI — spaCy | NLTK | RAG | OpenAI | Gemini | Open-source LLMs | Embeddings\n\nDatabases — PostgreSQL | MySQL | MongoDB | Qdrant | FAISS | Chroma\n\nCloud &amp; DevOps — AWS | GCP | Docker | GitHub Actions\n\nAPIs &amp; Frameworks — FastAPI | Flask | Streamli | Gradio\n\nData Analysis — Pandas | NumPy | Matplotlib | Plotly | Power BI\n\nOther Tools — Prometheus | Grafana | Git/GitHub | Linux | Pytest | LiveKit | Pydantic | LangSmith\n'},
#     {'title': 'VOLUNTEERING',
#      'node_id': '0012',
#      'page_index': 2,
#      'summary': '### VOLUNTEERING\n\nMember, AI Team - CIC Radix Team, Atlantis Underwater Robotics, ROV Competition\n\n- Built AI algorithms for underwater coral reef detection and plastic waste removal.\n',
#      'text': '### VOLUNTEERING\n\nMember, AI Team - CIC Radix Team, Atlantis Underwater Robotics, ROV Competition\n\n- Built AI algorithms for underwater coral reef detection and plastic waste removal.\n'}]},
#   '0002': {'title': 'PROFESSIONAL SUMMARY',
#    'node_id': '0002',
#    'page_index': 1,
#    'summary': '### PROFESSIONAL SUMMARY\n\nAI Engineer experienced in real-world GenAI systems, from LLM fine-tuning and agentic workflows to RAG pipelines and real-time voice assistants. Strong ML and Python foundation, with a deep interest in advancing Arabic AI applications.\n',
#    'text': '### PROFESSIONAL SUMMARY\n\nAI Engineer experienced in real-world GenAI systems, from LLM fine-tuning and agentic workflows to RAG pipelines and real-time voice assistants. Strong ML and Python foundation, with a deep interest in advancing Arabic AI applications.\n'},
#   '0003': {'title': 'PROFESSIONAL EXPERIENCE',
#    'node_id': '0003',
#    'page_index': 1,
#    'summary': '### PROFESSIONAL EXPERIENCE\n',
#    'text': '### PROFESSIONAL EXPERIENCE\n'},
#   '0004': {'title': 'EDUCATION',
#    'node_id': '0004',
#    'page_index': 1,
#    'prefix_summary': '### EDUCATION\n',
#    'text': '### EDUCATION\n',
#    'nodes': [{'title': 'ALX Africa – ExploreAI Academy,',
#      'node_id': '0005',
#      'page_index': 1,
#      'summary': '#### ALX Africa – ExploreAI Academy,\n\n05/2023 – 09/2024 | Cairo, Egypt\n\n**Scholarship in Data Science, 13-Month Program**\n\n- Included: 2 months of soft skills training and 11 months of data science studies in collaboration with ExploreAI Academy.\n- Covers: Excel, SQL, Power BI, Python, Machine Learning (ML), NLP, AWS Foundations.\n',
#      'text': '#### ALX Africa – ExploreAI Academy,\n\n05/2023 – 09/2024 | Cairo, Egypt\n\n**Scholarship in Data Science, 13-Month Program**\n\n- Included: 2 months of soft skills training and 11 months of data science studies in collaboration with ExploreAI Academy.\n- Covers: Excel, SQL, Power BI, Python, Machine Learning (ML), NLP, AWS Foundations.\n'},
#     {'title': 'Canadian International College (CIC),',
#      'node_id': '0006',
#      'page_index': 1,
#      'summary': '#### Canadian International College (CIC),\n\n09/2018 – 06/2023 | Cairo, Egypt\n\n**B.Sc in Electronics and Communication Engineering**\n\n- GPA: **3.52** | Rank: **3rd**\n- Graduation project: Web Application Firewall-based ML and NLP | Grade: **A+** | **Paper**  | **code**\n\nPROJECTS\n',
#      'text': '#### Canadian International College (CIC),\n\n09/2018 – 06/2023 | Cairo, Egypt\n\n**B.Sc in Electronics and Communication Engineering**\n\n- GPA: **3.52** | Rank: **3rd**\n- Graduation project: Web Application Firewall-based ML and NLP | Grade: **A+** | **Paper**  | **code**\n\nPROJECTS\n'},
#     {'title': 'Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory',
#      'node_id': '0007',
#      'page_index': 2,
#      'summary': '#### Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory\n\n- Translated business requirements into technical specifications, leading the team (UI/UX, Frontend, AI, QA/Test) and designing the agent and system architecture during the POC phase.\n- Implemented a LangGraph-based agent orchestration layer supporting text, voice, and visual (infographic) modalities across retrieval and response generation.\n- Built RAG pipelines using a vector database to ingest and retrieve domain-specific research content, balancing relevance, latency, and cost.\n- Added LLM observability and monitoring with LangSmith to track token usage, latency, and answers.\n',
#      'text': '#### Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory\n\n- Translated business requirements into technical specifications, leading the team (UI/UX, Frontend, AI, QA/Test) and designing the agent and system architecture during the POC phase.\n- Implemented a LangGraph-based agent orchestration layer supporting text, voice, and visual (infographic) modalities across retrieval and response generation.\n- Built RAG pipelines using a vector database to ingest and retrieve domain-specific research content, balancing relevance, latency, and cost.\n- Added LLM observability and monitoring with LangSmith to track token usage, latency, and answers.\n'},
#     {'title': 'Contract Analysis Agent based on Sharia and Law',
#      'node_id': '0008',
#      'page_index': 2,
#      'summary': '#### Contract Analysis Agent based on Sharia and Law\n\n- Developed a LangGraph RAG system with 5 concurrent nodes, cutting response time by ~80%.\n- Processed 32+ clauses/batch using async parallelism.\n- Delivered 10+ FastAPI endpoints for classification, scoring, and digitalization.\n\nTech Stack: Python, FastAPI, LangGraph, Reranking, Docker\n',
#      'text': '#### Contract Analysis Agent based on Sharia and Law\n\n- Developed a LangGraph RAG system with 5 concurrent nodes, cutting response time by ~80%.\n- Processed 32+ clauses/batch using async parallelism.\n- Delivered 10+ FastAPI endpoints for classification, scoring, and digitalization.\n\nTech Stack: Python, FastAPI, LangGraph, Reranking, Docker\n'},
#     {'title': 'Virtual CFO Agent',
#      'node_id': '0009',
#      'page_index': 2,
#      'summary': '#### Virtual CFO Agent\n\n- Built a multi-LLM financial reasoning workflow (6 interconnected models)\n- Implemented RAG for external knowledge and optimized pipelines, reducing latency by 83%.\n- Tech Stack: Python, LangChain, MySQL, PostgreSQL, MongoDB, Hugging Face, Docker\n',
#      'text': '#### Virtual CFO Agent\n\n- Built a multi-LLM financial reasoning workflow (6 interconnected models)\n- Implemented RAG for external knowledge and optimized pipelines, reducing latency by 83%.\n- Tech Stack: Python, LangChain, MySQL, PostgreSQL, MongoDB, Hugging Face, Docker\n'},
#     {'title': 'Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)',
#      'node_id': '0010',
#      'page_index': 2,
#      'summary': '#### Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)\n\n- Collected Saudi Arabic dialect speech data from YouTube and extracted transcripts using Whisper\n- Optimized inference using mixed precision (FP16), achieving RTF ≈ 0.35, on a 4GB VRAM\n- Deployed the model using vLLM with dynamic batching (batch size = 45), utilizing 23GB VRAM to achieve ~2-second latency and a throughput of 5 requests per second (RPS).\n',
#      'text': '#### Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)\n\n- Collected Saudi Arabic dialect speech data from YouTube and extracted transcripts using Whisper\n- Optimized inference using mixed precision (FP16), achieving RTF ≈ 0.35, on a 4GB VRAM\n- Deployed the model using vLLM with dynamic batching (batch size = 45), utilizing 23GB VRAM to achieve ~2-second latency and a throughput of 5 requests per second (RPS).\n'}]},
#   '0005': {'title': 'ALX Africa – ExploreAI Academy,',
#    'node_id': '0005',
#    'page_index': 1,
#    'summary': '#### ALX Africa – ExploreAI Academy,\n\n05/2023 – 09/2024 | Cairo, Egypt\n\n**Scholarship in Data Science, 13-Month Program**\n\n- Included: 2 months of soft skills training and 11 months of data science studies in collaboration with ExploreAI Academy.\n- Covers: Excel, SQL, Power BI, Python, Machine Learning (ML), NLP, AWS Foundations.\n',
#    'text': '#### ALX Africa – ExploreAI Academy,\n\n05/2023 – 09/2024 | Cairo, Egypt\n\n**Scholarship in Data Science, 13-Month Program**\n\n- Included: 2 months of soft skills training and 11 months of data science studies in collaboration with ExploreAI Academy.\n- Covers: Excel, SQL, Power BI, Python, Machine Learning (ML), NLP, AWS Foundations.\n'},
#   '0006': {'title': 'Canadian International College (CIC),',
#    'node_id': '0006',
#    'page_index': 1,
#    'summary': '#### Canadian International College (CIC),\n\n09/2018 – 06/2023 | Cairo, Egypt\n\n**B.Sc in Electronics and Communication Engineering**\n\n- GPA: **3.52** | Rank: **3rd**\n- Graduation project: Web Application Firewall-based ML and NLP | Grade: **A+** | **Paper**  | **code**\n\nPROJECTS\n',
#    'text': '#### Canadian International College (CIC),\n\n09/2018 – 06/2023 | Cairo, Egypt\n\n**B.Sc in Electronics and Communication Engineering**\n\n- GPA: **3.52** | Rank: **3rd**\n- Graduation project: Web Application Firewall-based ML and NLP | Grade: **A+** | **Paper**  | **code**\n\nPROJECTS\n'},
#   '0007': {'title': 'Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory',
#    'node_id': '0007',
#    'page_index': 2,
#    'summary': '#### Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory\n\n- Translated business requirements into technical specifications, leading the team (UI/UX, Frontend, AI, QA/Test) and designing the agent and system architecture during the POC phase.\n- Implemented a LangGraph-based agent orchestration layer supporting text, voice, and visual (infographic) modalities across retrieval and response generation.\n- Built RAG pipelines using a vector database to ingest and retrieve domain-specific research content, balancing relevance, latency, and cost.\n- Added LLM observability and monitoring with LangSmith to track token usage, latency, and answers.\n',
#    'text': '#### Virtual Assistant Agent (POC) – TRENDS Research &amp; Advisory\n\n- Translated business requirements into technical specifications, leading the team (UI/UX, Frontend, AI, QA/Test) and designing the agent and system architecture during the POC phase.\n- Implemented a LangGraph-based agent orchestration layer supporting text, voice, and visual (infographic) modalities across retrieval and response generation.\n- Built RAG pipelines using a vector database to ingest and retrieve domain-specific research content, balancing relevance, latency, and cost.\n- Added LLM observability and monitoring with LangSmith to track token usage, latency, and answers.\n'},
#   '0008': {'title': 'Contract Analysis Agent based on Sharia and Law',
#    'node_id': '0008',
#    'page_index': 2,
#    'summary': '#### Contract Analysis Agent based on Sharia and Law\n\n- Developed a LangGraph RAG system with 5 concurrent nodes, cutting response time by ~80%.\n- Processed 32+ clauses/batch using async parallelism.\n- Delivered 10+ FastAPI endpoints for classification, scoring, and digitalization.\n\nTech Stack: Python, FastAPI, LangGraph, Reranking, Docker\n',
#    'text': '#### Contract Analysis Agent based on Sharia and Law\n\n- Developed a LangGraph RAG system with 5 concurrent nodes, cutting response time by ~80%.\n- Processed 32+ clauses/batch using async parallelism.\n- Delivered 10+ FastAPI endpoints for classification, scoring, and digitalization.\n\nTech Stack: Python, FastAPI, LangGraph, Reranking, Docker\n'},
#   '0009': {'title': 'Virtual CFO Agent',
#    'node_id': '0009',
#    'page_index': 2,
#    'summary': '#### Virtual CFO Agent\n\n- Built a multi-LLM financial reasoning workflow (6 interconnected models)\n- Implemented RAG for external knowledge and optimized pipelines, reducing latency by 83%.\n- Tech Stack: Python, LangChain, MySQL, PostgreSQL, MongoDB, Hugging Face, Docker\n',
#    'text': '#### Virtual CFO Agent\n\n- Built a multi-LLM financial reasoning workflow (6 interconnected models)\n- Implemented RAG for external knowledge and optimized pipelines, reducing latency by 83%.\n- Tech Stack: Python, LangChain, MySQL, PostgreSQL, MongoDB, Hugging Face, Docker\n'},
#   '0010': {'title': 'Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)',
#    'node_id': '0010',
#    'page_index': 2,
#    'summary': '#### Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)\n\n- Collected Saudi Arabic dialect speech data from YouTube and extracted transcripts using Whisper\n- Optimized inference using mixed precision (FP16), achieving RTF ≈ 0.35, on a 4GB VRAM\n- Deployed the model using vLLM with dynamic batching (batch size = 45), utilizing 23GB VRAM to achieve ~2-second latency and a throughput of 5 requests per second (RPS).\n',
#    'text': '#### Real-Time Saudi Arabic Dialect Text-to-Speech (XTTS-V2 Fine-Tuning)\n\n- Collected Saudi Arabic dialect speech data from YouTube and extracted transcripts using Whisper\n- Optimized inference using mixed precision (FP16), achieving RTF ≈ 0.35, on a 4GB VRAM\n- Deployed the model using vLLM with dynamic batching (batch size = 45), utilizing 23GB VRAM to achieve ~2-second latency and a throughput of 5 requests per second (RPS).\n'},
#   '0011': {'title': 'SKILLS',
#    'node_id': '0011',
#    'page_index': 2,
#    'summary': '### SKILLS\n\nML/AI Frameworks — TensorFlow | PyTorch | Scikit-learn | Hugging Face | Transformers | LangChain | LangGraph | PEFT | BitsAndBytes | Unsloth | Ollama | vLLM\n\nNLP/GenAI — spaCy | NLTK | RAG | OpenAI | Gemini | Open-source LLMs | Embeddings\n\nDatabases — PostgreSQL | MySQL | MongoDB | Qdrant | FAISS | Chroma\n\nCloud &amp; DevOps — AWS | GCP | Docker | GitHub Actions\n\nAPIs &amp; Frameworks — FastAPI | Flask | Streamli | Gradio\n\nData Analysis — Pandas | NumPy | Matplotlib | Plotly | Power BI\n\nOther Tools — Prometheus | Grafana | Git/GitHub | Linux | Pytest | LiveKit | Pydantic | LangSmith\n',
#    'text': '### SKILLS\n\nML/AI Frameworks — TensorFlow | PyTorch | Scikit-learn | Hugging Face | Transformers | LangChain | LangGraph | PEFT | BitsAndBytes | Unsloth | Ollama | vLLM\n\nNLP/GenAI — spaCy | NLTK | RAG | OpenAI | Gemini | Open-source LLMs | Embeddings\n\nDatabases — PostgreSQL | MySQL | MongoDB | Qdrant | FAISS | Chroma\n\nCloud &amp; DevOps — AWS | GCP | Docker | GitHub Actions\n\nAPIs &amp; Frameworks — FastAPI | Flask | Streamli | Gradio\n\nData Analysis — Pandas | NumPy | Matplotlib | Plotly | Power BI\n\nOther Tools — Prometheus | Grafana | Git/GitHub | Linux | Pytest | LiveKit | Pydantic | LangSmith\n'},
#   '0012': {'title': 'VOLUNTEERING',
#    'node_id': '0012',
#    'page_index': 2,
#    'summary': '### VOLUNTEERING\n\nMember, AI Team - CIC Radix Team, Atlantis Underwater Robotics, ROV Competition\n\n- Built AI algorithms for underwater coral reef detection and plastic waste removal.\n',
#    'text': '### VOLUNTEERING\n\nMember, AI Team - CIC Radix Team, Atlantis Underwater Robotics, ROV Competition\n\n- Built AI algorithms for underwater coral reef detection and plastic waste removal.\n'}}}

# %%
def clean_child_nodes(nodes):
    cleaned = []

    for node in nodes:
        clean_node = {
            "node_id": node.get("node_id"),
            "title": node.get("title"),
            "page_num": node.get("page_index"),
            "node_text": node.get("text"),
            "child_nodes": []
        }

        # 🔁 clean children recursively
        if "nodes" in node:
            clean_node["child_nodes"] = clean_child_nodes(node["nodes"])

        cleaned.append(clean_node)

    return cleaned

# %%
pdfs_content = []

for item in target_docs:
    doc_index = item["doc_index"]
    target_ids = item["target_ids"]

    index = all_indexes.get(doc_index, {})

    pdf_content = {
        "pdf_title": docs_list["documents"][doc_index]["name"]
    }

    results = [
                {
                    "node_id": nid,
                    "title": index[nid].get("title"),
                    "page_num": index[nid].get("page_index"),
                    "node_text": index[nid].get("text"),
                    "child_nodes": clean_child_nodes(index[nid].get("nodes", []))
                }
                for nid in target_ids
                if nid in index
            ]

    pdf_content["pdf_related_content"] = results
    pdfs_content.append(pdf_content)

# %%
pdfs_content
# Out:
# [{'pdf_title': 'projects_portfolio_in_github.pdf',
#   'pdf_related_content': [{'node_id': '0007',
#     'title': 'Natural Language Processing (NLP):',
#     'page_num': 4,
#     'node_text': "## Natural Language Processing (NLP):\n\n- Text classification using TFIDF (https://colab.research.google.com/drive/19Jl8nvJL5kZ84d2qRi3VwwDMY2WL4ZIS?usp=sharing): The goal of this project is to develop a machine learning model that can accurately classify tweets as either related to real disasters or not.\n- Text Classification with GloVe and LSTM (https://colab.research.google.com/drive/1W6kHzMh7iX5y6JZV731teVVRKyyMpg_u?usp=sharing): This project employs LSTM neural networks for text classification on disaster-related messages. It preprocesses and tokenizes text data, utilizes pre-trained word embeddings, and trains the model with Keras. Finally, it evaluates the model's performance, generates predictions, and creates a submission file for Kaggle competition.\n\n- Text Generation with GRU (https://colab.research.google.com/drive/1mixPpl1DGjgSGhu2xYTx4Jyd4p1NHrjs?usp=sharing): This code employs TensorFlow and Keras to build a text generation model. It preprocesses Shakespearean text data, creating sequences for training. The model architecture includes an Embedding layer and a GRU layer. After training, the model can generate text based on given starting seeds. This approach facilitates the generation of coherent text sequences.\n\n- Seq2seq Translation model with LSTM implementation (https://colab.research.google.com/drive/1Ffq3WFRfRFoo-CNLidxCDbtO4jFEwcp0?usp=sharing)\n\n- Seq2seq Translation model with LSTM + Attention implementation (https://colab.research.google.com/drive/1B?tMIEDccE4WGBhwci-ylqXADdu_oXav?usp=sharing)\n\n- Transformers Implementation From scratch (https://colab.research.google.com/drive/1YqtJlJrpaPWtKueitdSCLb1v7tLYhqPZ?usp=sharing)\n\n- Text Classification With BERT huggingface (https://www.kaggle.com/code/abdalrahminmohammed/bert-fine-tuning-with-huggingface): -Leaderboard Score: 0.99872 (first in the Leaderboard)\n\n- Loaded the pre-trained distillery-base-uncased model for sequence classification.\n- Set up training arguments and fine-tuned the model using a Trainer object.\n- Trained the model on the tokenized datasets and evaluated it using accuracy and F1 score metrics.\n- Predicted on the validation set in batches, calculated evaluation metrics (confusion matrix, classification report, F1 score).\n- Achieved high accuracy and F1 score on the validation set, indicating a well-performing model.\n",
#     'child_nodes': []}]},
#  {'pdf_title': 'my_Linkedin.pdf',
#   'pdf_related_content': [{'node_id': '0002',
#     'title': 'Experience',
#     'page_num': 1,
#     'node_text': '## Experience\nElectro Pi\n1 year 8 months\n\nAI Engineer\nSeptember 2024 - Present (1 year 7 months)\nCairo, Egypt\n\n- Developed a modular decision-making system using 7 LLMs, incorporating session-based memory management (short/long-term) and advanced prompt engineering. Achieved 99% accuracy in financial reasoning and reduced average response time from 1 minute to 10 seconds.\n\n- Integrated Retrieval-Augmented Generation (RAG) to inject contextual financial regulations into LLM prompts, enabling dynamic generation of advanced financial charts and graphs with high relevance.\n\n- Refactored core components of the automation pipeline using OOP, SOLID principles, and best practices, reducing average code file size from 500+ lines to under 75 lines, significantly improving readability and maintainability.\n\n- Developed an AI sales agent for a cosmetics platform using LangGraph, enabling real-time product recommendations via live API calls. Improved system response time by  $\\sim 40\\%$  and integrated monitoring tools (Prometheus, Grafana) within a Dockerized CI/CD pipeline.\n\n- Contributed to voice agent systems using Gemini Live API and LiveKit with WebRTC, supporting real-time conversation flows and intelligent responses.\n\n- Contributed to computer vision projects for manufacturing safety and quality assurance, including image annotation, model training, and fine-tuning for real-time defect detection.\n',
#     'child_nodes': [{'node_id': '0003',
#       'title': 'AI Engineer',
#       'page_num': 2,
#       'node_text': '### AI Engineer\n\nAugust 2024 - September 2024 (2 months)\n\nCairo, Egypt\n\n- Contributed to real-world AI projects, including harmful prompt detection and RAG-powered AI assistance using LangChain.\n- Worked on an AI-driven platform designed to help companies manage finances more efficiently, leveraging LLMs and machine learning models.\n- Playedakeyrole in integrating LLMs with financial models to process JSON data from Excel files, enabling automated extraction and calculation of financial insights based on user queries.\n',
#       'child_nodes': []},
#      {'node_id': '0004',
#       'title': 'Sand Technologies',
#       'page_num': 2,
#       'node_text': '### Sand Technologies\n\nData Scientist &amp; AI Engineer\n\nSeptember 2024 - Present (1 year 7 months)\n\nAssist startups in harnessing data and integrating AI and LLMs into their projects.\n',
#       'child_nodes': []},
#      {'node_id': '0005',
#       'title': 'ALX Arabia',
#       'page_num': 2,
#       'node_text': '### ALX Arabia\n\nScholarship\n\nMay 2023 - September 2024 (1 year 5 months)\n\nCairo, Egypt\n\nThis scholarship consists of 3 months of soft skills and approximately 11 months of studying data science from the Explore AI Academy curriculum.\n',
#       'child_nodes': []},
#      {'node_id': '0006',
#       'title': 'AI Rahma Medical Center',
#       'page_num': 3,
#       'node_text': '### AI Rahma Medical Center\n',
#       'child_nodes': [{'node_id': '0007',
#         'title': 'Data Analyst',
#         'page_num': 3,
#         'node_text': "#### Data Analyst\n\nJune 2023 - September 2023 (4 months)\n\nCairo, Egypt\n\nAs a dedicated Data Analyst at Al-Rahma Medical Center, I played a pivotal role in driving data-driven decision-making for both the medical center and its eight affiliated pharmacies. Leveraging my expertise in data management and analytics, I contributed significantly to the growth and operational efficiency of the center.\n\nKey Achievements:\n\nData Transformation and Cleaning:\n\n- Successfully extracted and transformed data from the B-Connect program for pharmacy management, ensuring accuracy and consistency.\n- Utilized Excel to convert raw data into a comprehensive and organized format, laying the foundation for insightful analysis.\n\n# Data Preparation for Analysis:\n\n- Meticulously prepared and cleaned data sets, enhancing the quality of information available for analysis.\n- Conducted data conversion processes to facilitate seamless integration and interpretation, ensuring data readiness for in-depth analysis.\n\nDashboard Development:\n\n- Engineered a series of dynamic dashboards for both the medical center and each affiliated pharmacy, providing stakeholders with real-time insights into performance metrics.\n- These dashboards spanned a comprehensive view of the past five years, enabling informed decision-making and strategic planning.\n\nStrategic Decision Support:\n\n- Empowered decision-makers with actionable insights, facilitating strategic planning and growth initiatives for the center and affiliated pharmacies.\n- Collaborated closely with cross-functional teams to align data analytics with business objectives, ensuring data-driven decisions at every level.\n\nPage 3 of 4\n\nPage 4 of 4\n\nSYNC INTERN'S\nMachine Learning Intern\nApril 2023 - May 2023 (2 months)\n\nApplAi\nMachine Learning Intern\nJanuary 2023 - February 2023 (2 months)\nAin shames university\n\n---\n\nEducation\n\nCIC - Canadian International College\nElectrical, Electronics and Communications Engineering · (2018 - 2023)\n\nExploreAI Academy\nScholarship, Data science · (May 2023 - July 2024)\n",
#         'child_nodes': []}]}]},
#    {'node_id': '0005',
#     'title': 'ALX Arabia',
#     'page_num': 2,
#     'node_text': '### ALX Arabia\n\nScholarship\n\nMay 2023 - September 2024 (1 year 5 months)\n\nCairo, Egypt\n\nThis scholarship consists of 3 months of soft skills and approximately 11 months of studying data science from the Explore AI Academy curriculum.\n',
#     'child_nodes': []}]}]

# %% [markdown]
# # get related_content function

# %%
type(all_indexes)
# Out:
# dict

# %%
def get_related_content( all_indexes:dict ,docs_list:list , target_docs:list):


    try:
        pdfs_content = []

        for item in target_docs:
            doc_index = item["doc_index"]
            target_ids = item["target_ids"]

            index = all_indexes.get(doc_index, {})

            pdf_content = {
                "pdf_title": docs_list["documents"][doc_index]["name"]
            }

            results = [
                        {
                            "node_id": nid,
                            "title": index[nid].get("title"),
                            "page_num": index[nid].get("page_index"),
                            "node_text": index[nid].get("text"),
                            "child_nodes": clean_child_nodes(index[nid].get("nodes", []))
                        }
                        for nid in target_ids
                        if nid in index
                    ]

            pdf_content["pdf_related_content"] = results
            pdfs_content.append(pdf_content)

        return pdfs_content

    except Exception as e:
        logger.exception('Error while trying to get_tree_toc')

# %%
get_related_content(all_indexes , docs_list ,target_docs )
# Out:
# [{'pdf_title': 'projects_portfolio_in_github.pdf',
#   'pdf_related_content': [{'node_id': '0007',
#     'title': 'Natural Language Processing (NLP):',
#     'page_num': 4,
#     'node_text': "## Natural Language Processing (NLP):\n\n- Text classification using TFIDF (https://colab.research.google.com/drive/19Jl8nvJL5kZ84d2qRi3VwwDMY2WL4ZIS?usp=sharing): The goal of this project is to develop a machine learning model that can accurately classify tweets as either related to real disasters or not.\n- Text Classification with GloVe and LSTM (https://colab.research.google.com/drive/1W6kHzMh7iX5y6JZV731teVVRKyyMpg_u?usp=sharing): This project employs LSTM neural networks for text classification on disaster-related messages. It preprocesses and tokenizes text data, utilizes pre-trained word embeddings, and trains the model with Keras. Finally, it evaluates the model's performance, generates predictions, and creates a submission file for Kaggle competition.\n\n- Text Generation with GRU (https://colab.research.google.com/drive/1mixPpl1DGjgSGhu2xYTx4Jyd4p1NHrjs?usp=sharing): This code employs TensorFlow and Keras to build a text generation model. It preprocesses Shakespearean text data, creating sequences for training. The model architecture includes an Embedding layer and a GRU layer. After training, the model can generate text based on given starting seeds. This approach facilitates the generation of coherent text sequences.\n\n- Seq2seq Translation model with LSTM implementation (https://colab.research.google.com/drive/1Ffq3WFRfRFoo-CNLidxCDbtO4jFEwcp0?usp=sharing)\n\n- Seq2seq Translation model with LSTM + Attention implementation (https://colab.research.google.com/drive/1B?tMIEDccE4WGBhwci-ylqXADdu_oXav?usp=sharing)\n\n- Transformers Implementation From scratch (https://colab.research.google.com/drive/1YqtJlJrpaPWtKueitdSCLb1v7tLYhqPZ?usp=sharing)\n\n- Text Classification With BERT huggingface (https://www.kaggle.com/code/abdalrahminmohammed/bert-fine-tuning-with-huggingface): -Leaderboard Score: 0.99872 (first in the Leaderboard)\n\n- Loaded the pre-trained distillery-base-uncased model for sequence classification.\n- Set up training arguments and fine-tuned the model using a Trainer object.\n- Trained the model on the tokenized datasets and evaluated it using accuracy and F1 score metrics.\n- Predicted on the validation set in batches, calculated evaluation metrics (confusion matrix, classification report, F1 score).\n- Achieved high accuracy and F1 score on the validation set, indicating a well-performing model.\n",
#     'child_nodes': []}]},
#  {'pdf_title': 'my_Linkedin.pdf',
#   'pdf_related_content': [{'node_id': '0002',
#     'title': 'Experience',
#     'page_num': 1,
#     'node_text': '## Experience\nElectro Pi\n1 year 8 months\n\nAI Engineer\nSeptember 2024 - Present (1 year 7 months)\nCairo, Egypt\n\n- Developed a modular decision-making system using 7 LLMs, incorporating session-based memory management (short/long-term) and advanced prompt engineering. Achieved 99% accuracy in financial reasoning and reduced average response time from 1 minute to 10 seconds.\n\n- Integrated Retrieval-Augmented Generation (RAG) to inject contextual financial regulations into LLM prompts, enabling dynamic generation of advanced financial charts and graphs with high relevance.\n\n- Refactored core components of the automation pipeline using OOP, SOLID principles, and best practices, reducing average code file size from 500+ lines to under 75 lines, significantly improving readability and maintainability.\n\n- Developed an AI sales agent for a cosmetics platform using LangGraph, enabling real-time product recommendations via live API calls. Improved system response time by  $\\sim 40\\%$  and integrated monitoring tools (Prometheus, Grafana) within a Dockerized CI/CD pipeline.\n\n- Contributed to voice agent systems using Gemini Live API and LiveKit with WebRTC, supporting real-time conversation flows and intelligent responses.\n\n- Contributed to computer vision projects for manufacturing safety and quality assurance, including image annotation, model training, and fine-tuning for real-time defect detection.\n',
#     'child_nodes': [{'node_id': '0003',
#       'title': 'AI Engineer',
#       'page_num': 2,
#       'node_text': '### AI Engineer\n\nAugust 2024 - September 2024 (2 months)\n\nCairo, Egypt\n\n- Contributed to real-world AI projects, including harmful prompt detection and RAG-powered AI assistance using LangChain.\n- Worked on an AI-driven platform designed to help companies manage finances more efficiently, leveraging LLMs and machine learning models.\n- Playedakeyrole in integrating LLMs with financial models to process JSON data from Excel files, enabling automated extraction and calculation of financial insights based on user queries.\n',
#       'child_nodes': []},
#      {'node_id': '0004',
#       'title': 'Sand Technologies',
#       'page_num': 2,
#       'node_text': '### Sand Technologies\n\nData Scientist &amp; AI Engineer\n\nSeptember 2024 - Present (1 year 7 months)\n\nAssist startups in harnessing data and integrating AI and LLMs into their projects.\n',
#       'child_nodes': []},
#      {'node_id': '0005',
#       'title': 'ALX Arabia',
#       'page_num': 2,
#       'node_text': '### ALX Arabia\n\nScholarship\n\nMay 2023 - September 2024 (1 year 5 months)\n\nCairo, Egypt\n\nThis scholarship consists of 3 months of soft skills and approximately 11 months of studying data science from the Explore AI Academy curriculum.\n',
#       'child_nodes': []},
#      {'node_id': '0006',
#       'title': 'AI Rahma Medical Center',
#       'page_num': 3,
#       'node_text': '### AI Rahma Medical Center\n',
#       'child_nodes': [{'node_id': '0007',
#         'title': 'Data Analyst',
#         'page_num': 3,
#         'node_text': "#### Data Analyst\n\nJune 2023 - September 2023 (4 months)\n\nCairo, Egypt\n\nAs a dedicated Data Analyst at Al-Rahma Medical Center, I played a pivotal role in driving data-driven decision-making for both the medical center and its eight affiliated pharmacies. Leveraging my expertise in data management and analytics, I contributed significantly to the growth and operational efficiency of the center.\n\nKey Achievements:\n\nData Transformation and Cleaning:\n\n- Successfully extracted and transformed data from the B-Connect program for pharmacy management, ensuring accuracy and consistency.\n- Utilized Excel to convert raw data into a comprehensive and organized format, laying the foundation for insightful analysis.\n\n# Data Preparation for Analysis:\n\n- Meticulously prepared and cleaned data sets, enhancing the quality of information available for analysis.\n- Conducted data conversion processes to facilitate seamless integration and interpretation, ensuring data readiness for in-depth analysis.\n\nDashboard Development:\n\n- Engineered a series of dynamic dashboards for both the medical center and each affiliated pharmacy, providing stakeholders with real-time insights into performance metrics.\n- These dashboards spanned a comprehensive view of the past five years, enabling informed decision-making and strategic planning.\n\nStrategic Decision Support:\n\n- Empowered decision-makers with actionable insights, facilitating strategic planning and growth initiatives for the center and affiliated pharmacies.\n- Collaborated closely with cross-functional teams to align data analytics with business objectives, ensuring data-driven decisions at every level.\n\nPage 3 of 4\n\nPage 4 of 4\n\nSYNC INTERN'S\nMachine Learning Intern\nApril 2023 - May 2023 (2 months)\n\nApplAi\nMachine Learning Intern\nJanuary 2023 - February 2023 (2 months)\nAin shames university\n\n---\n\nEducation\n\nCIC - Canadian International College\nElectrical, Electronics and Communications Engineering · (2018 - 2023)\n\nExploreAI Academy\nScholarship, Data science · (May 2023 - July 2024)\n",
#         'child_nodes': []}]}]},
#    {'node_id': '0004',
#     'title': 'Sand Technologies',
#     'page_num': 2,
#     'node_text': '### Sand Technologies\n\nData Scientist &amp; AI Engineer\n\nSeptember 2024 - Present (1 year 7 months)\n\nAssist startups in harnessing data and integrating AI and LLMs into their projects.\n',
#     'child_nodes': []}]}]

# %% [markdown]
# # all function

# %%
def get_trees_titles( docs_list:list) -> list[dict]:
    try:
        
        docs_titles = [
            {
                "doc_index": i,
                "name": doc.get("name"),
                "description": doc.get("description")
            }
            for i, doc in enumerate(docs_list.get("documents", []))
        ]

        return docs_titles

    except Exception as e:
        logger.exception("Error while trying to get the tree titles")

# %%
def get_tree_toc(tree: list) -> list:
    try:
        toc_structure = []

        for node in tree:
            new_node = {
                "node_id": node.get("node_id"),
                "title": node.get("title"),
                "node_summary": node.get("node_summary") 
                                or node.get("summary") 
                                or node.get("prefix_summary", ""),
                "child_nodes": []
            }

            children = node.get("nodes", [])
            if children:
                new_node["child_nodes"] = get_tree_toc(children)

            toc_structure.append(new_node)

        return toc_structure

    except Exception:
        logger.exception("Error while trying to get_tree_toc")
        return []

# %%
def build_all_trees_index(pi_client: PageIndexClient, docs_list: dict) -> dict:
    """
    Build all trees once and store them in memory
    """
    all_trees = {}

    for i, doc in enumerate(docs_list.get("documents", [])):
        doc_id = doc["id"]

        tree_result = pi_client.get_tree(doc_id, node_summary=True)
        tree = tree_result.get("result", [])

        all_trees[i] = tree

    return all_trees

# %%
def get_docs_toc(
    pi_client: PageIndexClient,
    docs_list,
    docs_index: list,
    all_trees_index: dict = None   
):
    try:
        docs_tocs = []

        for i in docs_index:


            if all_trees_index and i in all_trees_index:
                tree = all_trees_index[i]

            else:
                # fallback (old behavior)
                doc_id = docs_list["documents"][i]['id']
                tree_result = pi_client.get_tree(doc_id, node_summary=True)
                tree = tree_result.get("result", [])

            docs_toc = {
                "doc_index": i,
                "doc_title": docs_list["documents"][i]["name"],
                "doc_toc": get_tree_toc(tree)
            }

            docs_tocs.append(docs_toc)

        return docs_tocs

    except Exception:
        logger.exception('Error while trying to get_docs_toc')

# %%
def build_index(nodes: list) -> dict:
    index = {}

    def dfs(node_list):
        for node in node_list:
            node_id = node.get("node_id")
            if node_id:
                index[node_id] = node

            children = node.get("nodes", [])
            if children:
                dfs(children)

    dfs(nodes)
    return index

# %%
def build_all_indexes(pi_client, docs_list):
    all_indexes = {}

    for i, doc in enumerate(docs_list.get("documents", [])):
        doc_id = doc["id"]

        tree_result = pi_client.get_tree(doc_id, node_summary=True)
        nodes = tree_result.get("result", [])

        all_indexes[i] = build_index(nodes)  # store index per doc

    return all_indexes

# %%
def clean_child_nodes(nodes: list) -> list:
    cleaned = []

    for node in nodes:
        cleaned.append({
            "node_id": node.get("node_id"),
            "title": node.get("title"),
            "page_num": node.get("page_index"),
            "node_text": node.get("text"),
            "child_nodes": clean_child_nodes(node.get("nodes", []))
        })

    return cleaned

# %%
def get_related_content( all_indexes:dict ,docs_list:list , target_docs:list):


    try:
        pdfs_content = []

        for item in target_docs:
            doc_index = item["doc_index"]
            target_ids = item["target_ids"]

            index = all_indexes.get(doc_index, {})

            pdf_content = {
                "pdf_title": docs_list["documents"][doc_index]["name"]
            }

            results = [
                        {
                            "node_id": nid,
                            "title": index[nid].get("title"),
                            "page_num": index[nid].get("page_index"),
                            "node_text": index[nid].get("text"),
                            "child_nodes": clean_child_nodes(index[nid].get("nodes", []))
                        }
                        for nid in target_ids
                        if nid in index
                    ]

            pdf_content["pdf_related_content"] = results
            pdfs_content.append(pdf_content)

        return pdfs_content

    except Exception as e:
        logger.exception('Error while trying to get_tree_toc')

# %% [markdown]
# # build the class

# %%
class TreeRetrieval:

    def __init__(self, pi_client: PageIndexClient):
        self.pi_client = pi_client
        self.docs_list = pi_client.list_documents()
        self.indexes = build_all_indexes(self.pi_client, self.docs_list)
        self.all_tree_index = build_all_trees_index(pi_client ,self.docs_list )
        

    def get_docs_titles(self):
        return get_tree_titles(self.docs_list)

    def get_toc(self, doc_indices: list): # doc_indices = [0 , 1 , 2 ...]
        return get_docs_toc(self.pi_client, self.docs_list, doc_indices , self.all_tree_index)

    def retrieve(self, target_docs: list[dict]): # target_docs = [{"doc_index": 0, "target_ids": [ "0007"]}]
        return get_related_content(self.indexes, self.docs_list, target_docs)

# %%
tr = TreeRetrieval(pi_client)

# %%
tr.get_docs_titles()
# Out:
# [{'doc_index': 0,
#   'name': 'projects_portfolio_in_github.pdf',
#   'description': 'This document outlines a data science portfolio showcasing projects in data analysis, visualization, machine learning, recommendation systems, time series forecasting, deep learning, and natural language processing.'},
#  {'doc_index': 1,
#   'name': 'my_Linkedin.pdf',
#   'description': 'This document outlines the experience of Abdelrahman Mohamed, an AI Engineer specializing in LLM agents, RAG pipelines, and real-time AI assistants, with roles at Electro Pi, Sand Technologies, and ALX Arabia.'},
#  {'doc_index': 2,
#   'name': 'Abdelrahman_Mohamed_CV_14.9_1.pdf',
#   'description': 'This document is a resume for Abdelrahman Mohamed, an AI/ML Engineer with experience in GenAI systems, LLM fine-tuning, RAG pipelines, and real-time voice assistants, with a focus on Arabic AI applications.'}]

# %%
tr.get_toc(doc_indices=[0 ])
# Out:
# [{'doc_index': 0,
#   'doc_title': 'projects_portfolio_in_github.pdf',
#   'doc_toc': [{'node_id': '0000',
#     'title': 'Data Science Portfolio',
#     'node_summary': '# Data Science Portfolio\n',
#     'child_nodes': []},
#    {'node_id': '0001',
#     'title': 'Skill Based Projects',
#     'node_summary': '# Skill Based Projects\n',
#     'child_nodes': [{'node_id': '0002',
#       'title': 'Data Analysis and Visualization:',
#       'node_summary': 'The text describes four data analysis and visualization projects: an EDA on Airbnb listings to understand demand trends; an analysis of electronics store sales data; a startup growth analysis with a focus on location, marketing, and revenue, including dashboard creation; and a project to track water funds for Maji Ndogo, emphasizing transparency and accountability by comparing budgets, project completion, team performance, and costs.',
#       'child_nodes': []},
#      {'node_id': '0003',
#       'title': 'Machine Learning:',
#       'node_summary': "## Machine Learning:\n\n- FastML With EDA python package (My own package) (https://github.com/Veto2922/Fast-Machine-Learning-With-EDA-python-package/tree/main/FastML_With_EDA): FastML_With_EDA is a versatile Python package designed to simplify the machine learning pipeline, from exploratory data analysis (EDA) and preprocessing to automated machine learning (AutoML) model training and evaluation. Whether you're a beginner or an experienced data scientist, FastML provides the tools you need to streamline your workflow and make data-driven decisions.\n- I also created a WEB APP (https://github.com/Veto2922/streamlit_app_for_FastML_With_EDA_python_package/tree/main) as GUI for this package\n",
#       'child_nodes': []},
#      {'node_id': '0004',
#       'title': 'Recommendation System',
#       'node_summary': '## Recommendation System\n\n- Rank and Knowledge base (https://github.com/Veto2922/Recommendation-system-course/tree/main/Task%201%20Rank-Based%2BKnowledge-Based%20Recommendations)\n- Content based (https://github.com/Veto2922/Movie-Recommender-System-content-based-)\n- Hybrid-based Book Recommendation System (https://github.com/Veto2922/hybrid-based-book-recommender-systems)\n',
#       'child_nodes': []},
#      {'node_id': '0005',
#       'title': 'Time series analysis and forecast',
#       'node_summary': '## Time series analysis and forecast\n\n- Monthly Retail Sales Forecasting (https://github.com/Veto2922/Advance-Monthly-Retail-Sales-Forecasting): This project involves forecasting the monthly sales for clothing and clothing accessory stores using LSTM (Long Short-Term Memory) neural networks. The dataset consists of monthly sales data (in millions of dollars, not seasonally adjusted) retrieved from the FRED, Federal Reserve Bank of St. Louis.\n- Time series forecasting using LSTM (https://github.com/Veto2922/Time-series-forecasting-using-LSTM/tree/main)\n',
#       'child_nodes': []},
#      {'node_id': '0006',
#       'title': 'Deep Learning:',
#       'node_summary': 'The text covers an introduction to Deep Learning and Artificial Neural Networks (ANN). It then details three projects utilizing TensorFlow and Keras: a regression project for housing price prediction involving data analysis and model building; a classification project for breast cancer diagnosis prediction that includes feature selection, data preprocessing, and overfitting mitigation techniques; and a deep learning project for predicting loan default on LendingClub data, focusing on historical loan features and loan status.',
#       'child_nodes': []},
#      {'node_id': '0007',
#       'title': 'Natural Language Processing (NLP):',
#       'node_summary': 'The text covers various Natural Language Processing (NLP) techniques and projects. These include text classification using TFIDF and GloVe with LSTM for disaster-related content, text generation with GRU, and sequence-to-sequence translation models implemented with LSTM and LSTM with Attention. It also details a from-scratch implementation of Transformers and a high-performing BERT-based text classification model using Huggingface, which achieved a top leaderboard score through fine-tuning and rigorous evaluation.',
#       'child_nodes': []}]}]}]

# %%
tr.retrieve(target_docs)
# Out:
# [{'pdf_title': 'projects_portfolio_in_github.pdf',
#   'pdf_related_content': [{'node_id': '0007',
#     'title': 'Natural Language Processing (NLP):',
#     'page_num': 4,
#     'node_text': "## Natural Language Processing (NLP):\n\n- Text classification using TFIDF (https://colab.research.google.com/drive/19Jl8nvJL5kZ84d2qRi3VwwDMY2WL4ZIS?usp=sharing): The goal of this project is to develop a machine learning model that can accurately classify tweets as either related to real disasters or not.\n- Text Classification with GloVe and LSTM (https://colab.research.google.com/drive/1W6kHzMh7iX5y6JZV731teVVRKyyMpg_u?usp=sharing): This project employs LSTM neural networks for text classification on disaster-related messages. It preprocesses and tokenizes text data, utilizes pre-trained word embeddings, and trains the model with Keras. Finally, it evaluates the model's performance, generates predictions, and creates a submission file for Kaggle competition.\n\n- Text Generation with GRU (https://colab.research.google.com/drive/1mixPpl1DGjgSGhu2xYTx4Jyd4p1NHrjs?usp=sharing): This code employs TensorFlow and Keras to build a text generation model. It preprocesses Shakespearean text data, creating sequences for training. The model architecture includes an Embedding layer and a GRU layer. After training, the model can generate text based on given starting seeds. This approach facilitates the generation of coherent text sequences.\n\n- Seq2seq Translation model with LSTM implementation (https://colab.research.google.com/drive/1Ffq3WFRfRFoo-CNLidxCDbtO4jFEwcp0?usp=sharing)\n\n- Seq2seq Translation model with LSTM + Attention implementation (https://colab.research.google.com/drive/1B?tMIEDccE4WGBhwci-ylqXADdu_oXav?usp=sharing)\n\n- Transformers Implementation From scratch (https://colab.research.google.com/drive/1YqtJlJrpaPWtKueitdSCLb1v7tLYhqPZ?usp=sharing)\n\n- Text Classification With BERT huggingface (https://www.kaggle.com/code/abdalrahminmohammed/bert-fine-tuning-with-huggingface): -Leaderboard Score: 0.99872 (first in the Leaderboard)\n\n- Loaded the pre-trained distillery-base-uncased model for sequence classification.\n- Set up training arguments and fine-tuned the model using a Trainer object.\n- Trained the model on the tokenized datasets and evaluated it using accuracy and F1 score metrics.\n- Predicted on the validation set in batches, calculated evaluation metrics (confusion matrix, classification report, F1 score).\n- Achieved high accuracy and F1 score on the validation set, indicating a well-performing model.\n",
#     'child_nodes': []}]},
#  {'pdf_title': 'my_Linkedin.pdf',
#   'pdf_related_content': [{'node_id': '0002',
#     'title': 'Experience',
#     'page_num': 1,
#     'node_text': '## Experience\nElectro Pi\n1 year 8 months\n\nAI Engineer\nSeptember 2024 - Present (1 year 7 months)\nCairo, Egypt\n\n- Developed a modular decision-making system using 7 LLMs, incorporating session-based memory management (short/long-term) and advanced prompt engineering. Achieved 99% accuracy in financial reasoning and reduced average response time from 1 minute to 10 seconds.\n\n- Integrated Retrieval-Augmented Generation (RAG) to inject contextual financial regulations into LLM prompts, enabling dynamic generation of advanced financial charts and graphs with high relevance.\n\n- Refactored core components of the automation pipeline using OOP, SOLID principles, and best practices, reducing average code file size from 500+ lines to under 75 lines, significantly improving readability and maintainability.\n\n- Developed an AI sales agent for a cosmetics platform using LangGraph, enabling real-time product recommendations via live API calls. Improved system response time by  $\\sim 40\\%$  and integrated monitoring tools (Prometheus, Grafana) within a Dockerized CI/CD pipeline.\n\n- Contributed to voice agent systems using Gemini Live API and LiveKit with WebRTC, supporting real-time conversation flows and intelligent responses.\n\n- Contributed to computer vision projects for manufacturing safety and quality assurance, including image annotation, model training, and fine-tuning for real-time defect detection.\n',
#     'child_nodes': [{'node_id': '0003',
#       'title': 'AI Engineer',
#       'page_num': 2,
#       'node_text': '### AI Engineer\n\nAugust 2024 - September 2024 (2 months)\n\nCairo, Egypt\n\n- Contributed to real-world AI projects, including harmful prompt detection and RAG-powered AI assistance using LangChain.\n- Worked on an AI-driven platform designed to help companies manage finances more efficiently, leveraging LLMs and machine learning models.\n- Playedakeyrole in integrating LLMs with financial models to process JSON data from Excel files, enabling automated extraction and calculation of financial insights based on user queries.\n',
#       'child_nodes': []},
#      {'node_id': '0004',
#       'title': 'Sand Technologies',
#       'page_num': 2,
#       'node_text': '### Sand Technologies\n\nData Scientist &amp; AI Engineer\n\nSeptember 2024 - Present (1 year 7 months)\n\nAssist startups in harnessing data and integrating AI and LLMs into their projects.\n',
#       'child_nodes': []},
#      {'node_id': '0005',
#       'title': 'ALX Arabia',
#       'page_num': 2,
#       'node_text': '### ALX Arabia\n\nScholarship\n\nMay 2023 - September 2024 (1 year 5 months)\n\nCairo, Egypt\n\nThis scholarship consists of 3 months of soft skills and approximately 11 months of studying data science from the Explore AI Academy curriculum.\n',
#       'child_nodes': []},
#      {'node_id': '0006',
#       'title': 'AI Rahma Medical Center',
#       'page_num': 3,
#       'node_text': '### AI Rahma Medical Center\n',
#       'child_nodes': [{'node_id': '0007',
#         'title': 'Data Analyst',
#         'page_num': 3,
#         'node_text': "#### Data Analyst\n\nJune 2023 - September 2023 (4 months)\n\nCairo, Egypt\n\nAs a dedicated Data Analyst at Al-Rahma Medical Center, I played a pivotal role in driving data-driven decision-making for both the medical center and its eight affiliated pharmacies. Leveraging my expertise in data management and analytics, I contributed significantly to the growth and operational efficiency of the center.\n\nKey Achievements:\n\nData Transformation and Cleaning:\n\n- Successfully extracted and transformed data from the B-Connect program for pharmacy management, ensuring accuracy and consistency.\n- Utilized Excel to convert raw data into a comprehensive and organized format, laying the foundation for insightful analysis.\n\n# Data Preparation for Analysis:\n\n- Meticulously prepared and cleaned data sets, enhancing the quality of information available for analysis.\n- Conducted data conversion processes to facilitate seamless integration and interpretation, ensuring data readiness for in-depth analysis.\n\nDashboard Development:\n\n- Engineered a series of dynamic dashboards for both the medical center and each affiliated pharmacy, providing stakeholders with real-time insights into performance metrics.\n- These dashboards spanned a comprehensive view of the past five years, enabling informed decision-making and strategic planning.\n\nStrategic Decision Support:\n\n- Empowered decision-makers with actionable insights, facilitating strategic planning and growth initiatives for the center and affiliated pharmacies.\n- Collaborated closely with cross-functional teams to align data analytics with business objectives, ensuring data-driven decisions at every level.\n\nPage 3 of 4\n\nPage 4 of 4\n\nSYNC INTERN'S\nMachine Learning Intern\nApril 2023 - May 2023 (2 months)\n\nApplAi\nMachine Learning Intern\nJanuary 2023 - February 2023 (2 months)\nAin shames university\n\n---\n\nEducation\n\nCIC - Canadian International College\nElectrical, Electronics and Communications Engineering · (2018 - 2023)\n\nExploreAI Academy\nScholarship, Data science · (May 2023 - July 2024)\n",
#         'child_nodes': []}]}]},
#    {'node_id': '0004',
#     'title': 'Sand Technologies',
#     'page_num': 2,
#     'node_text': '### Sand Technologies\n\nData Scientist &amp; AI Engineer\n\nSeptember 2024 - Present (1 year 7 months)\n\nAssist startups in harnessing data and integrating AI and LLMs into their projects.\n',
#     'child_nodes': []}]}]
